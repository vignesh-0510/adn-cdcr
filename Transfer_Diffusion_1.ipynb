# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#/content/drive/My Drive/Project/chest_xray/train

# %%
# Install required libraries
# !pip install diffusers transformers accelerate
# !pip install --upgrade diffusers  # Ensure the latest version
# !pip install huggingface_hub

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms
from torch.utils.data import DataLoader
from diffusers import UNet2DConditionModel, AutoencoderKL, DDPMScheduler
from transformers import CLIPTextModel, CLIPTokenizer
import torch.nn.functional as F
from torch.nn.utils import spectral_norm
import numpy as np
from PIL import Image
import os
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]

# %%
# Set random seeds for reproducibility
torch.manual_seed(0)
np.random.seed(0)

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

# Dataset path
dataset_path = '/content/drive/My Drive/Project/chest_xray/train'

# Transformations
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),  # Converts to [0, 1]
    transforms.Normalize([0.5], [0.5]),  # Normalizes to [-1, 1]
])
# Out:
# Using device: cuda

# %%
# Custom Dataset
from torch.utils.data import Dataset
import glob

class ChestXRayDataset(Dataset):
    def __init__(self, image_folder, transform=None):
        # Recursively search for images in subdirectories
        self.image_paths = glob.glob(os.path.join(image_folder, '**', '*.png'), recursive=True) + \
                           glob.glob(os.path.join(image_folder, '**', '*.jpg'), recursive=True) + \
                           glob.glob(os.path.join(image_folder, '**', '*.jpeg'), recursive=True)
        self.transform = transform

        print(f"Found {len(self.image_paths)} images in {image_folder}")

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image = Image.open(self.image_paths[idx]).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image

dataset = ChestXRayDataset(dataset_path, transform=transform)

# Check if dataset is empty
if len(dataset) == 0:
    raise ValueError(f"No images found in {dataset_path}. Please check the path and file extensions.")

data_loader = DataLoader(dataset, batch_size=2, shuffle=True)

# Load pre-trained models from Stable Diffusion
model_name = "stabilityai/stable-diffusion-2-1-base"

pretrained_unet = UNet2DConditionModel.from_pretrained(
    model_name, subfolder="unet"
).to(device)
pretrained_unet.eval()

vae = AutoencoderKL.from_pretrained(
    model_name, subfolder="vae"
).to(device)
vae.eval()

tokenizer = CLIPTokenizer.from_pretrained(
    model_name, subfolder="tokenizer"
)

text_encoder = CLIPTextModel.from_pretrained(
    model_name, subfolder="text_encoder"
).to(device)
text_encoder.eval()

# %%
# Freeze parameters of the pre-trained models
for param in pretrained_unet.parameters():
    param.requires_grad = False

for param in vae.parameters():
    param.requires_grad = False

for param in text_encoder.parameters():
    param.requires_grad = False
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-7d2c4a5edd06> in <cell line: 2>()
#       1 # Freeze parameters of the pre-trained models
# ----> 2 for param in pretrained_unet.parameters():
#       3     param.requires_grad = False
#       4
#       5 for param in vae.parameters():
#
# NameError: name 'pretrained_unet' is not defined

# %%
# Adaptation layer definition with residual connections
class AdaptationLayer(nn.Module):
    def __init__(self, channels):
        super(AdaptationLayer, self).__init__()
        self.conv1 = nn.Conv2d(channels, channels, kernel_size=3, padding=1)
        self.norm1 = nn.GroupNorm(num_groups=32, num_channels=channels)
        self.relu = nn.ReLU(inplace=False)

    def forward(self, x):
        residual = x
        out = self.conv1(x)
        out = self.norm1(out)
        out = self.relu(out)
        out = out + residual
        return out

# %%
# Function to get the number of channels from the model
def get_layer_output_channels():
    dummy_input = torch.randn(1, 4, 64, 64).to(device)
    dummy_timestep = torch.tensor([0], dtype=torch.long).to(device)
    dummy_encoder_hidden_states = torch.randn(1, 77, pretrained_unet.config.cross_attention_dim).to(device)

    output_channels = {}
    output_sizes = {}

    def hook_fn(name):
        def hook(module, input, output):
            if isinstance(output, tuple):
                out = output[0]
            else:
                out = output
            output_channels[name] = out.shape[1]
            output_sizes[name] = out.shape[2:]
        return hook

    hooks = []
    hooks.append(pretrained_unet.down_blocks[0].register_forward_hook(hook_fn('down_block_0')))
    hooks.append(pretrained_unet.down_blocks[1].register_forward_hook(hook_fn('down_block_1')))
    hooks.append(pretrained_unet.down_blocks[2].register_forward_hook(hook_fn('down_block_2')))
    hooks.append(pretrained_unet.mid_block.register_forward_hook(hook_fn('mid_block')))
    hooks.append(pretrained_unet.up_blocks[2].register_forward_hook(hook_fn('up_block_2')))
    hooks.append(pretrained_unet.up_blocks[1].register_forward_hook(hook_fn('up_block_1')))
    hooks.append(pretrained_unet.up_blocks[0].register_forward_hook(hook_fn('up_block_0')))

    with torch.no_grad():
        _ = pretrained_unet(dummy_input, dummy_timestep, dummy_encoder_hidden_states)

    for hook in hooks:
        hook.remove()

    return output_channels, output_sizes

# %%
# !pip install git+https://github.com/huggingface/transformers.git

from transformers import AutoProcessor, Blip2ForConditionalGeneration
import torch

processor = AutoProcessor.from_pretrained("Salesforce/blip2-opt-2.7b")
model = Blip2ForConditionalGeneration.from_pretrained("Salesforce/blip2-opt-2.7b", torch_dtype=torch.float16)
device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)

import requests
from PIL import Image

url = 'https://media.newyorker.com/cartoons/63dc6847be24a6a76d90eb99/master/w_1160,c_limit/230213_a26611_838.jpg'
image = Image.open(requests.get(url, stream=True).raw).convert('RGB')
display(image.resize((596, 437)))


inputs = processor(image, return_tensors="pt").to(device, torch.float16)
generated_ids = model.generate(**inputs, max_new_tokens=20)
generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)


print("Pixel values shape:", inputs.get("pixel_values", None).shape)
print("Input IDs shape:", inputs.get("input_ids", None).shape)
print(generated_text)

# %%
# Get actual output channels and sizes from the model
output_channels, output_sizes = get_layer_output_channels()
print("Output channels of each block:", output_channels)
print("Output sizes of each block:", output_sizes)

# Initialize adaptation layers with correct channel sizes
adaptation_layers = nn.ModuleDict()
for name, channels in output_channels.items():
    adaptation_layers[name] = AdaptationLayer(channels).to(device)

# Choose a feature map with larger spatial dimensions
# Let's use 'down_block_1' which has larger spatial dimensions
discriminator_input_layer = 'down_block_1'  # You can change this to 'down_block_0' for even larger size
# Out:
# Output channels of each block: {'down_block_0': 320, 'down_block_1': 640, 'down_block_2': 1280, 'mid_block': 1280, 'up_block_0': 1280, 'up_block_1': 1280, 'up_block_2': 640}
# Output sizes of each block: {'down_block_0': torch.Size([32, 32]), 'down_block_1': torch.Size([16, 16]), 'down_block_2': torch.Size([8, 8]), 'mid_block': torch.Size([8, 8]), 'up_block_0': torch.Size([16, 16]), 'up_block_1': torch.Size([32, 32]), 'up_block_2': torch.Size([64, 64])}

# %%
# Discriminator network with spectral normalization
class Discriminator(nn.Module):
    def __init__(self, input_channels):
        super(Discriminator, self).__init__()
        self.main = nn.Sequential(
            spectral_norm(nn.Conv2d(input_channels, 64, kernel_size=3, stride=2, padding=1)),
            nn.LeakyReLU(0.2, inplace=False),
            spectral_norm(nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1)),
            nn.LeakyReLU(0.2, inplace=False),
            spectral_norm(nn.Conv2d(128, 256, kernel_size=3, stride=2, padding=1)),
            nn.LeakyReLU(0.2, inplace=False),
            spectral_norm(nn.Conv2d(256, 512, kernel_size=3, stride=2, padding=1)),
            nn.LeakyReLU(0.2, inplace=False),
            nn.AdaptiveAvgPool2d(1),
            nn.Conv2d(512, 1, kernel_size=1, stride=1, padding=0),
        )

    def forward(self, x):
        x = self.main(x)
        return x.view(x.size(0), -1)

discriminator = Discriminator(output_channels[discriminator_input_layer]).to(device)

# %%
# Loss functions and optimizers
bce_loss = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(adaptation_layers.parameters(), lr=1e-4)
disc_optimizer = optim.Adam(discriminator.parameters(), lr=1e-6)

# %%
# Scheduler
scheduler = DDPMScheduler.from_pretrained(model_name, subfolder="scheduler")
# Out:
# scheduler/scheduler_config.json:   0%|          | 0.00/346 [00:00<?, ?B/s]

# %%
# Function to encode text prompts
def encode_prompts(prompts):
    text_inputs = tokenizer(
        prompts,
        padding="max_length",
        max_length=tokenizer.model_max_length,
        truncation=True,
        return_tensors="pt",
    )
    with torch.no_grad():
        text_embeddings = text_encoder(text_inputs.input_ids.to(device))[0]
    return text_embeddings

# %%
# Modified hook function
def create_hook(name):
    def hook(module, input, output):
        if isinstance(output, tuple):
            # Process the first element
            out0 = output[0]
            original_features[name] = out0.detach()
            adaptation_layer = adaptation_layers[name]
            adapted_out0 = adaptation_layer(out0)
            adapted_features[name] = adapted_out0
            # Return a tuple with the adapted output and the rest unchanged
            output = (adapted_out0,) + output[1:]
        else:
            # Process the output
            original_features[name] = output.detach()
            adaptation_layer = adaptation_layers[name]
            adapted_output = adaptation_layer(output)
            adapted_features[name] = adapted_output
            output = adapted_output
        return output
    return hook

# %%
# Training loop
epochs = 10  # Adjust as needed
adv_loss_weight = 0.1
cons_loss_weight = 0.0001

for epoch in range(epochs):
    for batch_idx, images in enumerate(data_loader):
        images = images.to(device)
        batch_size = images.size(0)

        # Encode images to latent space
        with torch.no_grad():
            latents = vae.encode(images).latent_dist.sample() * 0.18215  # Scaling factor from Stable Diffusion

        # Generate random noise
        noise = torch.randn_like(latents).to(device)

        # Sample random timesteps
        timesteps = torch.randint(0, scheduler.config.num_train_timesteps, (batch_size,), device=device).long()

        # Get noise corresponding to timesteps
        noisy_latents = scheduler.add_noise(latents, noise, timesteps)

        # Encode text prompts
        encoder_hidden_states = encode_prompts(["a chest X-ray image"] * batch_size)

        # Define dictionaries to store features for consistency loss
        adapted_features = {}
        original_features = {}

        # Register forward hooks
        hooks = []
        hooks.append(pretrained_unet.down_blocks[0].register_forward_hook(create_hook('down_block_0')))
        hooks.append(pretrained_unet.down_blocks[1].register_forward_hook(create_hook('down_block_1')))
        hooks.append(pretrained_unet.down_blocks[2].register_forward_hook(create_hook('down_block_2')))
        hooks.append(pretrained_unet.mid_block.register_forward_hook(create_hook('mid_block')))
        hooks.append(pretrained_unet.up_blocks[2].register_forward_hook(create_hook('up_block_2')))
        hooks.append(pretrained_unet.up_blocks[1].register_forward_hook(create_hook('up_block_1')))
        hooks.append(pretrained_unet.up_blocks[0].register_forward_hook(create_hook('up_block_0')))

        # Forward pass through the model with hooks
        model_pred = pretrained_unet(noisy_latents, timesteps, encoder_hidden_states).sample

        # Remove hooks
        for hook in hooks:
            hook.remove()

        # Compute losses
        # Diffusion loss
        target = noise
        diffusion_loss = F.mse_loss(model_pred, target)

        # Consistency loss
        cons_loss = 0
        for key in adapted_features.keys():
            # Ensure dimensions match
            adapted_feat = adapted_features[key]
            original_feat = original_features[key]

            # Adjust channels if needed
            if adapted_feat.shape[1] != original_feat.shape[1]:
                min_channels = min(adapted_feat.shape[1], original_feat.shape[1])
                adapted_feat = adapted_feat[:, :min_channels, :, :]
                original_feat = original_feat[:, :min_channels, :, :]

            cons_loss += F.mse_loss(adapted_feat, original_feat)

        # Adversarial loss
        # Use the feature from the selected layer as input to the discriminator
        disc_input_real = original_features[discriminator_input_layer]
        disc_input_fake = adapted_features[discriminator_input_layer]

        disc_optimizer.zero_grad()
        # Discriminator loss on real data
        disc_real = discriminator(disc_input_real.detach())
        real_labels = torch.ones_like(disc_real, device=device)
        disc_loss_real = bce_loss(disc_real, real_labels)

        # Discriminator loss on fake data
        disc_fake = discriminator(disc_input_fake.detach())
        fake_labels = torch.zeros_like(disc_fake, device=device)
        disc_loss_fake = bce_loss(disc_fake, fake_labels)

        disc_loss = (disc_loss_real + disc_loss_fake) / 2
        disc_loss.backward()
        disc_optimizer.step()

        # Generator adversarial loss
        adv_output = discriminator(disc_input_fake)
        adv_loss = bce_loss(adv_output, real_labels)

        # Total loss
        total_loss = diffusion_loss + cons_loss_weight * cons_loss + adv_loss_weight * adv_loss

        optimizer.zero_grad()
        total_loss.backward()
        optimizer.step()

        # Logging
        if batch_idx % 10 == 0:
            print(f"Epoch [{epoch+1}/{epochs}], Batch [{batch_idx}], Total Loss: {total_loss.item():.4f}, "
                  f"Diffusion Loss: {diffusion_loss.item():.4f}, Consistency Loss: {cons_loss.item():.4f}, "
                  f"Adversarial Loss: {adv_loss.item():.4f}")

# Save the trained adaptation layers
os.makedirs('saved_models', exist_ok=True)
torch.save(adaptation_layers.state_dict(), 'saved_models/adaptation_layers.pth')
torch.save(discriminator.state_dict(), 'saved_models/discriminator.pth')
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch [31/50], Batch [2200], Total Loss: 0.1014, Diffusion Loss: 0.0309, Consistency Loss: 12.0525, Adversarial Loss: 0.6929
# Epoch [31/50], Batch [2210], Total Loss: 0.2719, Diffusion Loss: 0.2014, Consistency Loss: 13.5040, Adversarial Loss: 0.6921
# Epoch [31/50], Batch [2220], Total Loss: 0.2620, Diffusion Loss: 0.1914, Consistency Loss: 13.2393, Adversarial Loss: 0.6927
# Epoch [31/50], Batch [2230], Total Loss: 0.1708, Diffusion Loss: 0.0998, Consistency Loss: 16.1581, Adversarial Loss: 0.6941
# Epoch [31/50], Batch [2240], Total Loss: 0.3831, Diffusion Loss: 0.3119, Consistency Loss: 17.0882, Adversarial Loss: 0.6947
# Epoch [31/50], Batch [2250], Total Loss: 0.1099, Diffusion Loss: 0.0393, Consistency Loss: 13.5381, Adversarial Loss: 0.6927
# Epoch [31/50], Batch [2260], Total Loss: 0.1257, Diffusion Loss: 0.0549, Consistency Loss: 14.3212, Adversarial Loss: 0.6934
# Epoch [31/50], Batch [2270], Total Loss: 0.1997, Diffusion Loss: 0.1287, Consistency Loss: 16.6242, Adversarial Loss: 0.6935
# Epoch [31/50], Batch [2280], Total Loss: 0.1347, Diffusion Loss: 0.0638, Consistency Loss: 15.2293, Adversarial Loss: 0.6938
# Epoch [31/50], Batch [2290], Total Loss: 0.2250, Diffusion Loss: 0.1544, Consistency Loss: 12.9343, Adversarial Loss: 0.6927
# Epoch [31/50], Batch [2300], Total Loss: 0.0940, Diffusion Loss: 0.0234, Consistency Loss: 12.1151, Adversarial Loss: 0.6936
# Epoch [31/50], Batch [2310], Total Loss: 0.0982, Diffusion Loss: 0.0277, Consistency Loss: 12.3434, Adversarial Loss: 0.6922
# Epoch [31/50], Batch [2320], Total Loss: 0.1014, Diffusion Loss: 0.0307, Consistency Loss: 14.6598, Adversarial Loss: 0.6926
# Epoch [31/50], Batch [2330], Total Loss: 0.0793, Diffusion Loss: 0.0089, Consistency Loss: 9.9424, Adversarial Loss: 0.6934
# Epoch [31/50], Batch [2340], Total Loss: 0.1396, Diffusion Loss: 0.0690, Consistency Loss: 12.7406, Adversarial Loss: 0.6933
# Epoch [31/50], Batch [2350], Total Loss: 0.2124, Diffusion Loss: 0.1418, Consistency Loss: 12.7883, Adversarial Loss: 0.6938
# Epoch [31/50], Batch [2360], Total Loss: 0.2880, Diffusion Loss: 0.2170, Consistency Loss: 16.8719, Adversarial Loss: 0.6924
# Epoch [31/50], Batch [2370], Total Loss: 0.1721, Diffusion Loss: 0.1011, Consistency Loss: 16.7180, Adversarial Loss: 0.6929
# Epoch [31/50], Batch [2380], Total Loss: 0.2162, Diffusion Loss: 0.1451, Consistency Loss: 16.5200, Adversarial Loss: 0.6943
# Epoch [31/50], Batch [2390], Total Loss: 0.2467, Diffusion Loss: 0.1754, Consistency Loss: 17.1107, Adversarial Loss: 0.6955
# Epoch [31/50], Batch [2400], Total Loss: 0.1415, Diffusion Loss: 0.0705, Consistency Loss: 16.3019, Adversarial Loss: 0.6940
# Epoch [31/50], Batch [2410], Total Loss: 0.1574, Diffusion Loss: 0.0864, Consistency Loss: 15.6838, Adversarial Loss: 0.6936
# Epoch [31/50], Batch [2420], Total Loss: 0.0927, Diffusion Loss: 0.0220, Consistency Loss: 13.1535, Adversarial Loss: 0.6943
# Epoch [31/50], Batch [2430], Total Loss: 0.1684, Diffusion Loss: 0.0976, Consistency Loss: 13.4836, Adversarial Loss: 0.6938
# Epoch [31/50], Batch [2440], Total Loss: 0.1076, Diffusion Loss: 0.0371, Consistency Loss: 13.1322, Adversarial Loss: 0.6926
# Epoch [31/50], Batch [2450], Total Loss: 0.1168, Diffusion Loss: 0.0462, Consistency Loss: 12.7051, Adversarial Loss: 0.6937
# Epoch [31/50], Batch [2460], Total Loss: 0.1032, Diffusion Loss: 0.0327, Consistency Loss: 12.5644, Adversarial Loss: 0.6926
# Epoch [31/50], Batch [2470], Total Loss: 0.1688, Diffusion Loss: 0.0980, Consistency Loss: 16.2690, Adversarial Loss: 0.6919
# Epoch [31/50], Batch [2480], Total Loss: 0.1055, Diffusion Loss: 0.0348, Consistency Loss: 12.2472, Adversarial Loss: 0.6941
# Epoch [31/50], Batch [2490], Total Loss: 0.3424, Diffusion Loss: 0.2714, Consistency Loss: 17.1956, Adversarial Loss: 0.6924
# Epoch [31/50], Batch [2500], Total Loss: 0.1094, Diffusion Loss: 0.0390, Consistency Loss: 12.0232, Adversarial Loss: 0.6920
# Epoch [31/50], Batch [2510], Total Loss: 0.1778, Diffusion Loss: 0.1070, Consistency Loss: 14.4521, Adversarial Loss: 0.6933
# Epoch [31/50], Batch [2520], Total Loss: 0.2303, Diffusion Loss: 0.1595, Consistency Loss: 15.5046, Adversarial Loss: 0.6923
# Epoch [31/50], Batch [2530], Total Loss: 0.1714, Diffusion Loss: 0.1007, Consistency Loss: 12.5742, Adversarial Loss: 0.6944
# Epoch [31/50], Batch [2540], Total Loss: 0.0872, Diffusion Loss: 0.0168, Consistency Loss: 11.1954, Adversarial Loss: 0.6929
# Epoch [31/50], Batch [2550], Total Loss: 0.2675, Diffusion Loss: 0.1966, Consistency Loss: 16.4515, Adversarial Loss: 0.6924
# Epoch [31/50], Batch [2560], Total Loss: 0.4765, Diffusion Loss: 0.4054, Consistency Loss: 17.0287, Adversarial Loss: 0.6938
# Epoch [31/50], Batch [2570], Total Loss: 0.3102, Diffusion Loss: 0.2391, Consistency Loss: 16.5575, Adversarial Loss: 0.6945
# Epoch [31/50], Batch [2580], Total Loss: 0.0781, Diffusion Loss: 0.0078, Consistency Loss: 9.5212, Adversarial Loss: 0.6933
# Epoch [31/50], Batch [2590], Total Loss: 0.1327, Diffusion Loss: 0.0617, Consistency Loss: 15.6373, Adversarial Loss: 0.6941
# Epoch [31/50], Batch [2600], Total Loss: 0.1337, Diffusion Loss: 0.0630, Consistency Loss: 14.7642, Adversarial Loss: 0.6922
# Epoch [32/50], Batch [0], Total Loss: 0.1550, Diffusion Loss: 0.0842, Consistency Loss: 15.6484, Adversarial Loss: 0.6929
# Epoch [32/50], Batch [10], Total Loss: 0.1435, Diffusion Loss: 0.0726, Consistency Loss: 16.3790, Adversarial Loss: 0.6922
# Epoch [32/50], Batch [20], Total Loss: 0.2221, Diffusion Loss: 0.1512, Consistency Loss: 16.6771, Adversarial Loss: 0.6922
# Epoch [32/50], Batch [30], Total Loss: 0.2581, Diffusion Loss: 0.1871, Consistency Loss: 17.2461, Adversarial Loss: 0.6923
# Epoch [32/50], Batch [40], Total Loss: 0.1256, Diffusion Loss: 0.0550, Consistency Loss: 12.6143, Adversarial Loss: 0.6933
# Epoch [32/50], Batch [50], Total Loss: 0.0755, Diffusion Loss: 0.0054, Consistency Loss: 8.4663, Adversarial Loss: 0.6928
# Epoch [32/50], Batch [60], Total Loss: 0.2932, Diffusion Loss: 0.2222, Consistency Loss: 17.0729, Adversarial Loss: 0.6928
# Epoch [32/50], Batch [70], Total Loss: 0.0782, Diffusion Loss: 0.0079, Consistency Loss: 9.3152, Adversarial Loss: 0.6934
# Epoch [32/50], Batch [80], Total Loss: 0.1765, Diffusion Loss: 0.1056, Consistency Loss: 16.3751, Adversarial Loss: 0.6924
# Epoch [32/50], Batch [90], Total Loss: 0.3020, Diffusion Loss: 0.2310, Consistency Loss: 16.7617, Adversarial Loss: 0.6930
# Epoch [32/50], Batch [100], Total Loss: 0.2453, Diffusion Loss: 0.1745, Consistency Loss: 12.4802, Adversarial Loss: 0.6948
# Epoch [32/50], Batch [110], Total Loss: 0.0797, Diffusion Loss: 0.0095, Consistency Loss: 10.0415, Adversarial Loss: 0.6925
# Epoch [32/50], Batch [120], Total Loss: 0.1831, Diffusion Loss: 0.1122, Consistency Loss: 16.8518, Adversarial Loss: 0.6923
# Epoch [32/50], Batch [130], Total Loss: 0.2172, Diffusion Loss: 0.1461, Consistency Loss: 16.5942, Adversarial Loss: 0.6936
# Epoch [32/50], Batch [140], Total Loss: 0.1273, Diffusion Loss: 0.0566, Consistency Loss: 15.0450, Adversarial Loss: 0.6923
# Epoch [32/50], Batch [150], Total Loss: 0.1465, Diffusion Loss: 0.0755, Consistency Loss: 16.5886, Adversarial Loss: 0.6938
# Epoch [32/50], Batch [160], Total Loss: 0.2140, Diffusion Loss: 0.1431, Consistency Loss: 16.5224, Adversarial Loss: 0.6932
# Epoch [32/50], Batch [170], Total Loss: 0.2260, Diffusion Loss: 0.1551, Consistency Loss: 16.7730, Adversarial Loss: 0.6923
# Epoch [32/50], Batch [180], Total Loss: 0.0922, Diffusion Loss: 0.0218, Consistency Loss: 11.5762, Adversarial Loss: 0.6930
# Epoch [32/50], Batch [190], Total Loss: 0.1458, Diffusion Loss: 0.0751, Consistency Loss: 14.4944, Adversarial Loss: 0.6928
# Epoch [32/50], Batch [200], Total Loss: 0.0853, Diffusion Loss: 0.0148, Consistency Loss: 10.9328, Adversarial Loss: 0.6936
# Epoch [32/50], Batch [210], Total Loss: 0.1285, Diffusion Loss: 0.0579, Consistency Loss: 13.4159, Adversarial Loss: 0.6928
# Epoch [32/50], Batch [220], Total Loss: 0.1211, Diffusion Loss: 0.0503, Consistency Loss: 14.9879, Adversarial Loss: 0.6929
# Epoch [32/50], Batch [230], Total Loss: 0.1813, Diffusion Loss: 0.1108, Consistency Loss: 13.2034, Adversarial Loss: 0.6922
# Epoch [32/50], Batch [240], Total Loss: 0.1668, Diffusion Loss: 0.0961, Consistency Loss: 14.4300, Adversarial Loss: 0.6933
# Epoch [32/50], Batch [250], Total Loss: 0.1380, Diffusion Loss: 0.0671, Consistency Loss: 15.9210, Adversarial Loss: 0.6934
# Epoch [32/50], Batch [260], Total Loss: 0.4567, Diffusion Loss: 0.3857, Consistency Loss: 17.2699, Adversarial Loss: 0.6921
# Epoch [32/50], Batch [270], Total Loss: 0.1039, Diffusion Loss: 0.0331, Consistency Loss: 15.4638, Adversarial Loss: 0.6929
# Epoch [32/50], Batch [280], Total Loss: 0.2282, Diffusion Loss: 0.1578, Consistency Loss: 12.8485, Adversarial Loss: 0.6912
# Epoch [32/50], Batch [290], Total Loss: 0.0827, Diffusion Loss: 0.0123, Consistency Loss: 10.8677, Adversarial Loss: 0.6933
# Epoch [32/50], Batch [300], Total Loss: 0.3515, Diffusion Loss: 0.2805, Consistency Loss: 17.0796, Adversarial Loss: 0.6929
# Epoch [32/50], Batch [310], Total Loss: 0.0720, Diffusion Loss: 0.0018, Consistency Loss: 8.0234, Adversarial Loss: 0.6940
# Epoch [32/50], Batch [320], Total Loss: 0.0763, Diffusion Loss: 0.0061, Consistency Loss: 8.7269, Adversarial Loss: 0.6929
# Epoch [32/50], Batch [330], Total Loss: 0.1906, Diffusion Loss: 0.1197, Consistency Loss: 16.5756, Adversarial Loss: 0.6926
# Epoch [32/50], Batch [340], Total Loss: 0.1489, Diffusion Loss: 0.0781, Consistency Loss: 15.8646, Adversarial Loss: 0.6922
# Epoch [32/50], Batch [350], Total Loss: 0.1811, Diffusion Loss: 0.1100, Consistency Loss: 16.7159, Adversarial Loss: 0.6940
# Epoch [32/50], Batch [360], Total Loss: 0.1451, Diffusion Loss: 0.0743, Consistency Loss: 16.1798, Adversarial Loss: 0.6924
# Epoch [32/50], Batch [370], Total Loss: 0.2032, Diffusion Loss: 0.1323, Consistency Loss: 16.8197, Adversarial Loss: 0.6923
# Epoch [32/50], Batch [380], Total Loss: 0.2734, Diffusion Loss: 0.2024, Consistency Loss: 17.3379, Adversarial Loss: 0.6927
# Epoch [32/50], Batch [390], Total Loss: 0.1185, Diffusion Loss: 0.0479, Consistency Loss: 12.9336, Adversarial Loss: 0.6935
# Epoch [32/50], Batch [400], Total Loss: 0.1532, Diffusion Loss: 0.0824, Consistency Loss: 16.2467, Adversarial Loss: 0.6922
# Epoch [32/50], Batch [410], Total Loss: 0.1016, Diffusion Loss: 0.0310, Consistency Loss: 12.6279, Adversarial Loss: 0.6936
# Epoch [32/50], Batch [420], Total Loss: 0.1191, Diffusion Loss: 0.0485, Consistency Loss: 12.8149, Adversarial Loss: 0.6928
# Epoch [32/50], Batch [430], Total Loss: 0.0934, Diffusion Loss: 0.0229, Consistency Loss: 11.9971, Adversarial Loss: 0.6933
# Epoch [32/50], Batch [440], Total Loss: 0.1061, Diffusion Loss: 0.0355, Consistency Loss: 12.7827, Adversarial Loss: 0.6932
# Epoch [32/50], Batch [450], Total Loss: 0.1561, Diffusion Loss: 0.0852, Consistency Loss: 16.5819, Adversarial Loss: 0.6924
# Epoch [32/50], Batch [460], Total Loss: 0.1377, Diffusion Loss: 0.0671, Consistency Loss: 13.5885, Adversarial Loss: 0.6928
# Epoch [32/50], Batch [470], Total Loss: 0.3085, Diffusion Loss: 0.2375, Consistency Loss: 16.5877, Adversarial Loss: 0.6937
# Epoch [32/50], Batch [480], Total Loss: 0.1337, Diffusion Loss: 0.0629, Consistency Loss: 14.7447, Adversarial Loss: 0.6931
# Epoch [32/50], Batch [490], Total Loss: 0.1712, Diffusion Loss: 0.1004, Consistency Loss: 15.9364, Adversarial Loss: 0.6923
# Epoch [32/50], Batch [500], Total Loss: 0.0745, Diffusion Loss: 0.0043, Consistency Loss: 8.5146, Adversarial Loss: 0.6928
# Epoch [32/50], Batch [510], Total Loss: 0.1222, Diffusion Loss: 0.0512, Consistency Loss: 15.6830, Adversarial Loss: 0.6940
# Epoch [32/50], Batch [520], Total Loss: 0.0790, Diffusion Loss: 0.0088, Consistency Loss: 9.9290, Adversarial Loss: 0.6928
# Epoch [32/50], Batch [530], Total Loss: 0.2617, Diffusion Loss: 0.1907, Consistency Loss: 16.8819, Adversarial Loss: 0.6924
# Epoch [32/50], Batch [540], Total Loss: 0.2439, Diffusion Loss: 0.1731, Consistency Loss: 16.4165, Adversarial Loss: 0.6919
# Epoch [32/50], Batch [550], Total Loss: 0.2616, Diffusion Loss: 0.1910, Consistency Loss: 13.8321, Adversarial Loss: 0.6924
# Epoch [32/50], Batch [560], Total Loss: 0.1968, Diffusion Loss: 0.1259, Consistency Loss: 16.8860, Adversarial Loss: 0.6921
# Epoch [32/50], Batch [570], Total Loss: 0.3384, Diffusion Loss: 0.2675, Consistency Loss: 17.1770, Adversarial Loss: 0.6911
# Epoch [32/50], Batch [580], Total Loss: 0.0942, Diffusion Loss: 0.0236, Consistency Loss: 13.1307, Adversarial Loss: 0.6934
# Epoch [32/50], Batch [590], Total Loss: 0.1400, Diffusion Loss: 0.0696, Consistency Loss: 12.9580, Adversarial Loss: 0.6914
# Epoch [32/50], Batch [600], Total Loss: 0.1931, Diffusion Loss: 0.1222, Consistency Loss: 17.0156, Adversarial Loss: 0.6918
# Epoch [32/50], Batch [610], Total Loss: 0.3022, Diffusion Loss: 0.2317, Consistency Loss: 12.4406, Adversarial Loss: 0.6923
# Epoch [32/50], Batch [620], Total Loss: 0.0813, Diffusion Loss: 0.0109, Consistency Loss: 10.1861, Adversarial Loss: 0.6934
# Epoch [32/50], Batch [630], Total Loss: 0.1078, Diffusion Loss: 0.0371, Consistency Loss: 14.4386, Adversarial Loss: 0.6927
# Epoch [32/50], Batch [640], Total Loss: 0.2024, Diffusion Loss: 0.1316, Consistency Loss: 14.2520, Adversarial Loss: 0.6933
# Epoch [32/50], Batch [650], Total Loss: 0.2851, Diffusion Loss: 0.2144, Consistency Loss: 14.4271, Adversarial Loss: 0.6921
# Epoch [32/50], Batch [660], Total Loss: 0.1817, Diffusion Loss: 0.1108, Consistency Loss: 17.0473, Adversarial Loss: 0.6919
# Epoch [32/50], Batch [670], Total Loss: 0.2684, Diffusion Loss: 0.1973, Consistency Loss: 16.9803, Adversarial Loss: 0.6945
# Epoch [32/50], Batch [680], Total Loss: 0.0728, Diffusion Loss: 0.0027, Consistency Loss: 8.1214, Adversarial Loss: 0.6932
# Epoch [32/50], Batch [690], Total Loss: 0.2014, Diffusion Loss: 0.1301, Consistency Loss: 17.0629, Adversarial Loss: 0.6960
# Epoch [32/50], Batch [700], Total Loss: 0.2164, Diffusion Loss: 0.1453, Consistency Loss: 17.0250, Adversarial Loss: 0.6945
# Epoch [32/50], Batch [710], Total Loss: 0.1366, Diffusion Loss: 0.0656, Consistency Loss: 15.3539, Adversarial Loss: 0.6938
# Epoch [32/50], Batch [720], Total Loss: 0.1451, Diffusion Loss: 0.0743, Consistency Loss: 14.3572, Adversarial Loss: 0.6938
# Epoch [32/50], Batch [730], Total Loss: 0.0808, Diffusion Loss: 0.0104, Consistency Loss: 9.9803, Adversarial Loss: 0.6936
# Epoch [32/50], Batch [740], Total Loss: 0.1440, Diffusion Loss: 0.0732, Consistency Loss: 16.4186, Adversarial Loss: 0.6917
# Epoch [32/50], Batch [750], Total Loss: 0.2215, Diffusion Loss: 0.1505, Consistency Loss: 17.4190, Adversarial Loss: 0.6933
# Epoch [32/50], Batch [760], Total Loss: 0.4765, Diffusion Loss: 0.4054, Consistency Loss: 16.7332, Adversarial Loss: 0.6938
# Epoch [32/50], Batch [770], Total Loss: 0.0889, Diffusion Loss: 0.0183, Consistency Loss: 12.4338, Adversarial Loss: 0.6927
# Epoch [32/50], Batch [780], Total Loss: 0.1157, Diffusion Loss: 0.0451, Consistency Loss: 13.2146, Adversarial Loss: 0.6930
# Epoch [32/50], Batch [790], Total Loss: 0.2737, Diffusion Loss: 0.2026, Consistency Loss: 17.3514, Adversarial Loss: 0.6929
# Epoch [32/50], Batch [800], Total Loss: 0.1494, Diffusion Loss: 0.0784, Consistency Loss: 16.6671, Adversarial Loss: 0.6932
# Epoch [32/50], Batch [810], Total Loss: 0.1468, Diffusion Loss: 0.0759, Consistency Loss: 15.1668, Adversarial Loss: 0.6944
# Epoch [32/50], Batch [820], Total Loss: 0.1269, Diffusion Loss: 0.0563, Consistency Loss: 12.6132, Adversarial Loss: 0.6933
# Epoch [32/50], Batch [830], Total Loss: 0.2314, Diffusion Loss: 0.1603, Consistency Loss: 16.8144, Adversarial Loss: 0.6940
# Epoch [32/50], Batch [840], Total Loss: 0.3399, Diffusion Loss: 0.2692, Consistency Loss: 14.8165, Adversarial Loss: 0.6927
# Epoch [32/50], Batch [850], Total Loss: 0.0887, Diffusion Loss: 0.0183, Consistency Loss: 12.0026, Adversarial Loss: 0.6928
# Epoch [32/50], Batch [860], Total Loss: 0.0804, Diffusion Loss: 0.0100, Consistency Loss: 10.5573, Adversarial Loss: 0.6931
# Epoch [32/50], Batch [870], Total Loss: 0.1022, Diffusion Loss: 0.0316, Consistency Loss: 12.6551, Adversarial Loss: 0.6933
# Epoch [32/50], Batch [880], Total Loss: 0.2092, Diffusion Loss: 0.1386, Consistency Loss: 12.7018, Adversarial Loss: 0.6932
# Epoch [32/50], Batch [890], Total Loss: 0.3280, Diffusion Loss: 0.2569, Consistency Loss: 17.0176, Adversarial Loss: 0.6936
# Epoch [32/50], Batch [900], Total Loss: 0.0817, Diffusion Loss: 0.0114, Consistency Loss: 9.9325, Adversarial Loss: 0.6926
# Epoch [32/50], Batch [910], Total Loss: 0.1027, Diffusion Loss: 0.0321, Consistency Loss: 13.0956, Adversarial Loss: 0.6929
# Epoch [32/50], Batch [920], Total Loss: 0.3057, Diffusion Loss: 0.2350, Consistency Loss: 13.5011, Adversarial Loss: 0.6935
# Epoch [32/50], Batch [930], Total Loss: 0.2931, Diffusion Loss: 0.2222, Consistency Loss: 15.9737, Adversarial Loss: 0.6932
# Epoch [32/50], Batch [940], Total Loss: 0.2830, Diffusion Loss: 0.2121, Consistency Loss: 17.0993, Adversarial Loss: 0.6920
# Epoch [32/50], Batch [950], Total Loss: 0.2207, Diffusion Loss: 0.1502, Consistency Loss: 13.5016, Adversarial Loss: 0.6911
# Epoch [32/50], Batch [960], Total Loss: 0.2279, Diffusion Loss: 0.1572, Consistency Loss: 15.0901, Adversarial Loss: 0.6921
# Epoch [32/50], Batch [970], Total Loss: 0.1163, Diffusion Loss: 0.0454, Consistency Loss: 14.6458, Adversarial Loss: 0.6941
# Epoch [32/50], Batch [980], Total Loss: 0.1695, Diffusion Loss: 0.0986, Consistency Loss: 15.3894, Adversarial Loss: 0.6936
# Epoch [32/50], Batch [990], Total Loss: 0.0861, Diffusion Loss: 0.0157, Consistency Loss: 11.6022, Adversarial Loss: 0.6920
# Epoch [32/50], Batch [1000], Total Loss: 0.0774, Diffusion Loss: 0.0070, Consistency Loss: 10.1435, Adversarial Loss: 0.6932
# Epoch [32/50], Batch [1010], Total Loss: 0.0844, Diffusion Loss: 0.0142, Consistency Loss: 10.3840, Adversarial Loss: 0.6922
# Epoch [32/50], Batch [1020], Total Loss: 0.2484, Diffusion Loss: 0.1774, Consistency Loss: 16.9881, Adversarial Loss: 0.6936
# Epoch [32/50], Batch [1030], Total Loss: 0.1681, Diffusion Loss: 0.0972, Consistency Loss: 16.4461, Adversarial Loss: 0.6925
# Epoch [32/50], Batch [1040], Total Loss: 0.1522, Diffusion Loss: 0.0812, Consistency Loss: 16.6137, Adversarial Loss: 0.6932
# Epoch [32/50], Batch [1050], Total Loss: 0.2087, Diffusion Loss: 0.1377, Consistency Loss: 16.9268, Adversarial Loss: 0.6932
# Epoch [32/50], Batch [1060], Total Loss: 0.2420, Diffusion Loss: 0.1709, Consistency Loss: 15.7407, Adversarial Loss: 0.6950
# Epoch [32/50], Batch [1070], Total Loss: 0.2008, Diffusion Loss: 0.1299, Consistency Loss: 16.6843, Adversarial Loss: 0.6923
# Epoch [32/50], Batch [1080], Total Loss: 0.3560, Diffusion Loss: 0.2849, Consistency Loss: 17.1375, Adversarial Loss: 0.6940
# Epoch [32/50], Batch [1090], Total Loss: 0.1781, Diffusion Loss: 0.1073, Consistency Loss: 14.7432, Adversarial Loss: 0.6931
# Epoch [32/50], Batch [1100], Total Loss: 0.2705, Diffusion Loss: 0.1996, Consistency Loss: 16.4339, Adversarial Loss: 0.6927
# Epoch [32/50], Batch [1110], Total Loss: 0.1220, Diffusion Loss: 0.0513, Consistency Loss: 13.5554, Adversarial Loss: 0.6933
# Epoch [32/50], Batch [1120], Total Loss: 0.0821, Diffusion Loss: 0.0117, Consistency Loss: 10.2593, Adversarial Loss: 0.6937
# Epoch [32/50], Batch [1130], Total Loss: 0.0942, Diffusion Loss: 0.0237, Consistency Loss: 12.2116, Adversarial Loss: 0.6935
# Epoch [32/50], Batch [1140], Total Loss: 0.0723, Diffusion Loss: 0.0021, Consistency Loss: 7.9479, Adversarial Loss: 0.6943
# Epoch [32/50], Batch [1150], Total Loss: 0.0731, Diffusion Loss: 0.0029, Consistency Loss: 8.2718, Adversarial Loss: 0.6933
# Epoch [32/50], Batch [1160], Total Loss: 0.1363, Diffusion Loss: 0.0653, Consistency Loss: 16.2757, Adversarial Loss: 0.6933
# Epoch [32/50], Batch [1170], Total Loss: 0.2672, Diffusion Loss: 0.1961, Consistency Loss: 16.6907, Adversarial Loss: 0.6939
# Epoch [32/50], Batch [1180], Total Loss: 0.2385, Diffusion Loss: 0.1678, Consistency Loss: 13.1830, Adversarial Loss: 0.6934
# Epoch [32/50], Batch [1190], Total Loss: 0.0860, Diffusion Loss: 0.0154, Consistency Loss: 12.2960, Adversarial Loss: 0.6940
# Epoch [32/50], Batch [1200], Total Loss: 0.2364, Diffusion Loss: 0.1655, Consistency Loss: 17.3921, Adversarial Loss: 0.6920
# Epoch [32/50], Batch [1210], Total Loss: 0.2603, Diffusion Loss: 0.1894, Consistency Loss: 15.5024, Adversarial Loss: 0.6933
# Epoch [32/50], Batch [1220], Total Loss: 0.1515, Diffusion Loss: 0.0805, Consistency Loss: 15.6089, Adversarial Loss: 0.6943
# Epoch [32/50], Batch [1230], Total Loss: 0.0973, Diffusion Loss: 0.0267, Consistency Loss: 13.2470, Adversarial Loss: 0.6925
# Epoch [32/50], Batch [1240], Total Loss: 0.4177, Diffusion Loss: 0.3468, Consistency Loss: 16.8660, Adversarial Loss: 0.6925
# Epoch [32/50], Batch [1250], Total Loss: 0.0851, Diffusion Loss: 0.0147, Consistency Loss: 10.7347, Adversarial Loss: 0.6928
# Epoch [32/50], Batch [1260], Total Loss: 0.1738, Diffusion Loss: 0.1030, Consistency Loss: 16.3194, Adversarial Loss: 0.6913
# Epoch [32/50], Batch [1270], Total Loss: 0.0893, Diffusion Loss: 0.0188, Consistency Loss: 10.6522, Adversarial Loss: 0.6941
# Epoch [32/50], Batch [1280], Total Loss: 0.1449, Diffusion Loss: 0.0740, Consistency Loss: 16.3590, Adversarial Loss: 0.6928
# Epoch [32/50], Batch [1290], Total Loss: 0.1611, Diffusion Loss: 0.0905, Consistency Loss: 12.8967, Adversarial Loss: 0.6929
# Epoch [32/50], Batch [1300], Total Loss: 0.0790, Diffusion Loss: 0.0086, Consistency Loss: 10.1054, Adversarial Loss: 0.6934
# Epoch [32/50], Batch [1310], Total Loss: 0.1145, Diffusion Loss: 0.0440, Consistency Loss: 12.7192, Adversarial Loss: 0.6925
# Epoch [32/50], Batch [1320], Total Loss: 0.1667, Diffusion Loss: 0.0960, Consistency Loss: 12.8640, Adversarial Loss: 0.6941
# Epoch [32/50], Batch [1330], Total Loss: 0.0754, Diffusion Loss: 0.0052, Consistency Loss: 8.6043, Adversarial Loss: 0.6929
# Epoch [32/50], Batch [1340], Total Loss: 0.1087, Diffusion Loss: 0.0382, Consistency Loss: 12.9013, Adversarial Loss: 0.6923
# Epoch [32/50], Batch [1350], Total Loss: 0.1169, Diffusion Loss: 0.0461, Consistency Loss: 14.7194, Adversarial Loss: 0.6932
# Epoch [32/50], Batch [1360], Total Loss: 0.1082, Diffusion Loss: 0.0376, Consistency Loss: 12.8202, Adversarial Loss: 0.6931
# Epoch [32/50], Batch [1370], Total Loss: 0.3710, Diffusion Loss: 0.2998, Consistency Loss: 17.2563, Adversarial Loss: 0.6950
# Epoch [32/50], Batch [1380], Total Loss: 0.2022, Diffusion Loss: 0.1310, Consistency Loss: 16.9278, Adversarial Loss: 0.6946
# Epoch [32/50], Batch [1390], Total Loss: 0.1527, Diffusion Loss: 0.0816, Consistency Loss: 16.6273, Adversarial Loss: 0.6945
# Epoch [32/50], Batch [1400], Total Loss: 0.0794, Diffusion Loss: 0.0090, Consistency Loss: 10.2194, Adversarial Loss: 0.6930
# Epoch [32/50], Batch [1410], Total Loss: 0.2395, Diffusion Loss: 0.1685, Consistency Loss: 16.8800, Adversarial Loss: 0.6938
# Epoch [32/50], Batch [1420], Total Loss: 0.0936, Diffusion Loss: 0.0230, Consistency Loss: 13.2218, Adversarial Loss: 0.6926
# Epoch [32/50], Batch [1430], Total Loss: 0.1154, Diffusion Loss: 0.0444, Consistency Loss: 15.9817, Adversarial Loss: 0.6937
# Epoch [32/50], Batch [1440], Total Loss: 0.1597, Diffusion Loss: 0.0892, Consistency Loss: 12.7600, Adversarial Loss: 0.6928
# Epoch [32/50], Batch [1450], Total Loss: 0.1081, Diffusion Loss: 0.0376, Consistency Loss: 12.4485, Adversarial Loss: 0.6931
# Epoch [32/50], Batch [1460], Total Loss: 0.2056, Diffusion Loss: 0.1348, Consistency Loss: 16.6668, Adversarial Loss: 0.6916
# Epoch [32/50], Batch [1470], Total Loss: 0.3029, Diffusion Loss: 0.2316, Consistency Loss: 17.1749, Adversarial Loss: 0.6953
# Epoch [32/50], Batch [1480], Total Loss: 0.0762, Diffusion Loss: 0.0060, Consistency Loss: 9.1918, Adversarial Loss: 0.6927
# Epoch [32/50], Batch [1490], Total Loss: 0.0890, Diffusion Loss: 0.0186, Consistency Loss: 11.7828, Adversarial Loss: 0.6926
# Epoch [32/50], Batch [1500], Total Loss: 0.3020, Diffusion Loss: 0.2311, Consistency Loss: 15.6594, Adversarial Loss: 0.6929
# Epoch [32/50], Batch [1510], Total Loss: 0.1006, Diffusion Loss: 0.0300, Consistency Loss: 12.8025, Adversarial Loss: 0.6938
# Epoch [32/50], Batch [1520], Total Loss: 0.1073, Diffusion Loss: 0.0364, Consistency Loss: 14.9169, Adversarial Loss: 0.6945
# Epoch [32/50], Batch [1530], Total Loss: 0.0881, Diffusion Loss: 0.0176, Consistency Loss: 11.7264, Adversarial Loss: 0.6930
# Epoch [32/50], Batch [1540], Total Loss: 0.0867, Diffusion Loss: 0.0162, Consistency Loss: 10.5636, Adversarial Loss: 0.6943
# Epoch [32/50], Batch [1550], Total Loss: 0.1415, Diffusion Loss: 0.0706, Consistency Loss: 15.6708, Adversarial Loss: 0.6934
# Epoch [32/50], Batch [1560], Total Loss: 0.1314, Diffusion Loss: 0.0608, Consistency Loss: 13.8208, Adversarial Loss: 0.6923
# Epoch [32/50], Batch [1570], Total Loss: 0.1025, Diffusion Loss: 0.0319, Consistency Loss: 13.4162, Adversarial Loss: 0.6925
# Epoch [32/50], Batch [1580], Total Loss: 0.3105, Diffusion Loss: 0.2399, Consistency Loss: 12.7844, Adversarial Loss: 0.6932
# Epoch [32/50], Batch [1590], Total Loss: 0.1276, Diffusion Loss: 0.0569, Consistency Loss: 12.5712, Adversarial Loss: 0.6937
# Epoch [32/50], Batch [1600], Total Loss: 0.1276, Diffusion Loss: 0.0569, Consistency Loss: 13.4030, Adversarial Loss: 0.6939
# Epoch [32/50], Batch [1610], Total Loss: 0.2884, Diffusion Loss: 0.2177, Consistency Loss: 13.4493, Adversarial Loss: 0.6935
# Epoch [32/50], Batch [1620], Total Loss: 0.2942, Diffusion Loss: 0.2236, Consistency Loss: 14.1317, Adversarial Loss: 0.6922
# Epoch [32/50], Batch [1630], Total Loss: 0.1506, Diffusion Loss: 0.0801, Consistency Loss: 13.3229, Adversarial Loss: 0.6916
# Epoch [32/50], Batch [1640], Total Loss: 0.3539, Diffusion Loss: 0.2830, Consistency Loss: 16.9600, Adversarial Loss: 0.6916
# Epoch [32/50], Batch [1650], Total Loss: 0.1351, Diffusion Loss: 0.0642, Consistency Loss: 16.1413, Adversarial Loss: 0.6931
# Epoch [32/50], Batch [1660], Total Loss: 0.4069, Diffusion Loss: 0.3359, Consistency Loss: 17.2673, Adversarial Loss: 0.6930
# Epoch [32/50], Batch [1670], Total Loss: 0.2788, Diffusion Loss: 0.2077, Consistency Loss: 17.1960, Adversarial Loss: 0.6937
# Epoch [32/50], Batch [1680], Total Loss: 0.2656, Diffusion Loss: 0.1947, Consistency Loss: 15.8273, Adversarial Loss: 0.6933
# Epoch [32/50], Batch [1690], Total Loss: 0.0791, Diffusion Loss: 0.0088, Consistency Loss: 10.1453, Adversarial Loss: 0.6936
# Epoch [32/50], Batch [1700], Total Loss: 0.2267, Diffusion Loss: 0.1559, Consistency Loss: 16.3477, Adversarial Loss: 0.6916
# Epoch [32/50], Batch [1710], Total Loss: 0.2975, Diffusion Loss: 0.2264, Consistency Loss: 17.4959, Adversarial Loss: 0.6931
# Epoch [32/50], Batch [1720], Total Loss: 0.2085, Diffusion Loss: 0.1378, Consistency Loss: 13.8392, Adversarial Loss: 0.6929
# Epoch [32/50], Batch [1730], Total Loss: 0.3629, Diffusion Loss: 0.2921, Consistency Loss: 15.2799, Adversarial Loss: 0.6924
# Epoch [32/50], Batch [1740], Total Loss: 0.0825, Diffusion Loss: 0.0122, Consistency Loss: 10.2510, Adversarial Loss: 0.6928
# Epoch [32/50], Batch [1750], Total Loss: 0.2480, Diffusion Loss: 0.1770, Consistency Loss: 16.9817, Adversarial Loss: 0.6929
# Epoch [32/50], Batch [1760], Total Loss: 0.0878, Diffusion Loss: 0.0174, Consistency Loss: 10.5333, Adversarial Loss: 0.6939
# Epoch [32/50], Batch [1770], Total Loss: 0.2540, Diffusion Loss: 0.1830, Consistency Loss: 17.3181, Adversarial Loss: 0.6928
# Epoch [32/50], Batch [1780], Total Loss: 0.3292, Diffusion Loss: 0.2582, Consistency Loss: 17.1825, Adversarial Loss: 0.6925
# Epoch [32/50], Batch [1790], Total Loss: 0.1201, Diffusion Loss: 0.0494, Consistency Loss: 13.3213, Adversarial Loss: 0.6932
# Epoch [32/50], Batch [1800], Total Loss: 0.2130, Diffusion Loss: 0.1421, Consistency Loss: 16.9793, Adversarial Loss: 0.6927
# Epoch [32/50], Batch [1810], Total Loss: 0.2222, Diffusion Loss: 0.1511, Consistency Loss: 16.8020, Adversarial Loss: 0.6942
# Epoch [32/50], Batch [1820], Total Loss: 0.1338, Diffusion Loss: 0.0628, Consistency Loss: 16.3145, Adversarial Loss: 0.6931
# Epoch [32/50], Batch [1830], Total Loss: 0.0768, Diffusion Loss: 0.0067, Consistency Loss: 9.2105, Adversarial Loss: 0.6920
# Epoch [32/50], Batch [1840], Total Loss: 0.1444, Diffusion Loss: 0.0733, Consistency Loss: 16.7748, Adversarial Loss: 0.6938
# Epoch [32/50], Batch [1850], Total Loss: 0.2909, Diffusion Loss: 0.2198, Consistency Loss: 17.5782, Adversarial Loss: 0.6942
# Epoch [32/50], Batch [1860], Total Loss: 0.2055, Diffusion Loss: 0.1349, Consistency Loss: 13.3466, Adversarial Loss: 0.6935
# Epoch [32/50], Batch [1870], Total Loss: 0.1501, Diffusion Loss: 0.0795, Consistency Loss: 13.1127, Adversarial Loss: 0.6925
# Epoch [32/50], Batch [1880], Total Loss: 0.2615, Diffusion Loss: 0.1908, Consistency Loss: 12.8605, Adversarial Loss: 0.6943
# Epoch [32/50], Batch [1890], Total Loss: 0.2732, Diffusion Loss: 0.2023, Consistency Loss: 14.2244, Adversarial Loss: 0.6951
# Epoch [32/50], Batch [1900], Total Loss: 0.0819, Diffusion Loss: 0.0114, Consistency Loss: 11.6708, Adversarial Loss: 0.6931
# Epoch [32/50], Batch [1910], Total Loss: 0.0823, Diffusion Loss: 0.0119, Consistency Loss: 11.0123, Adversarial Loss: 0.6928
# Epoch [32/50], Batch [1920], Total Loss: 0.3863, Diffusion Loss: 0.3157, Consistency Loss: 13.6522, Adversarial Loss: 0.6922
# Epoch [32/50], Batch [1930], Total Loss: 0.1083, Diffusion Loss: 0.0378, Consistency Loss: 12.4948, Adversarial Loss: 0.6929
# Epoch [32/50], Batch [1940], Total Loss: 0.2803, Diffusion Loss: 0.2095, Consistency Loss: 16.1389, Adversarial Loss: 0.6922
# Epoch [32/50], Batch [1950], Total Loss: 0.1313, Diffusion Loss: 0.0604, Consistency Loss: 15.5253, Adversarial Loss: 0.6929
# Epoch [32/50], Batch [1960], Total Loss: 0.2966, Diffusion Loss: 0.2259, Consistency Loss: 13.0424, Adversarial Loss: 0.6939
# Epoch [32/50], Batch [1970], Total Loss: 0.0998, Diffusion Loss: 0.0293, Consistency Loss: 12.6521, Adversarial Loss: 0.6917
# Epoch [32/50], Batch [1980], Total Loss: 0.0876, Diffusion Loss: 0.0170, Consistency Loss: 11.7900, Adversarial Loss: 0.6938
# Epoch [32/50], Batch [1990], Total Loss: 0.3121, Diffusion Loss: 0.2411, Consistency Loss: 17.1992, Adversarial Loss: 0.6932
# Epoch [32/50], Batch [2000], Total Loss: 0.3425, Diffusion Loss: 0.2719, Consistency Loss: 13.3465, Adversarial Loss: 0.6926
# Epoch [32/50], Batch [2010], Total Loss: 0.1222, Diffusion Loss: 0.0515, Consistency Loss: 12.9294, Adversarial Loss: 0.6942
# Epoch [32/50], Batch [2020], Total Loss: 0.0743, Diffusion Loss: 0.0041, Consistency Loss: 8.5964, Adversarial Loss: 0.6937
# Epoch [32/50], Batch [2030], Total Loss: 0.2081, Diffusion Loss: 0.1372, Consistency Loss: 15.5601, Adversarial Loss: 0.6935
# Epoch [32/50], Batch [2040], Total Loss: 0.2344, Diffusion Loss: 0.1638, Consistency Loss: 13.0810, Adversarial Loss: 0.6925
# Epoch [32/50], Batch [2050], Total Loss: 0.1320, Diffusion Loss: 0.0615, Consistency Loss: 12.8208, Adversarial Loss: 0.6923
# Epoch [32/50], Batch [2060], Total Loss: 0.2985, Diffusion Loss: 0.2280, Consistency Loss: 13.5133, Adversarial Loss: 0.6910
# Epoch [32/50], Batch [2070], Total Loss: 0.3216, Diffusion Loss: 0.2510, Consistency Loss: 12.9449, Adversarial Loss: 0.6925
# Epoch [32/50], Batch [2080], Total Loss: 0.1921, Diffusion Loss: 0.1214, Consistency Loss: 13.7534, Adversarial Loss: 0.6929
# Epoch [32/50], Batch [2090], Total Loss: 0.2309, Diffusion Loss: 0.1603, Consistency Loss: 12.9458, Adversarial Loss: 0.6933
# Epoch [32/50], Batch [2100], Total Loss: 0.2244, Diffusion Loss: 0.1532, Consistency Loss: 16.0999, Adversarial Loss: 0.6953
# Epoch [32/50], Batch [2110], Total Loss: 0.1236, Diffusion Loss: 0.0529, Consistency Loss: 13.8594, Adversarial Loss: 0.6930
# Epoch [32/50], Batch [2120], Total Loss: 0.1447, Diffusion Loss: 0.0738, Consistency Loss: 15.8070, Adversarial Loss: 0.6930
# Epoch [32/50], Batch [2130], Total Loss: 0.0831, Diffusion Loss: 0.0126, Consistency Loss: 10.2249, Adversarial Loss: 0.6942
# Epoch [32/50], Batch [2140], Total Loss: 0.1890, Diffusion Loss: 0.1179, Consistency Loss: 17.6626, Adversarial Loss: 0.6932
# Epoch [32/50], Batch [2150], Total Loss: 0.1017, Diffusion Loss: 0.0311, Consistency Loss: 12.7344, Adversarial Loss: 0.6928
# Epoch [32/50], Batch [2160], Total Loss: 0.0835, Diffusion Loss: 0.0132, Consistency Loss: 10.9188, Adversarial Loss: 0.6926
# Epoch [32/50], Batch [2170], Total Loss: 0.2875, Diffusion Loss: 0.2166, Consistency Loss: 17.6683, Adversarial Loss: 0.6911
# Epoch [32/50], Batch [2180], Total Loss: 0.0875, Diffusion Loss: 0.0170, Consistency Loss: 11.5548, Adversarial Loss: 0.6938
# Epoch [32/50], Batch [2190], Total Loss: 0.1809, Diffusion Loss: 0.1099, Consistency Loss: 16.7452, Adversarial Loss: 0.6930
# Epoch [32/50], Batch [2200], Total Loss: 0.1528, Diffusion Loss: 0.0822, Consistency Loss: 13.7184, Adversarial Loss: 0.6924
# Epoch [32/50], Batch [2210], Total Loss: 0.1025, Diffusion Loss: 0.0321, Consistency Loss: 12.2188, Adversarial Loss: 0.6920
# Epoch [32/50], Batch [2220], Total Loss: 0.4160, Diffusion Loss: 0.3453, Consistency Loss: 15.3019, Adversarial Loss: 0.6922
# Epoch [32/50], Batch [2230], Total Loss: 0.1795, Diffusion Loss: 0.1085, Consistency Loss: 16.0018, Adversarial Loss: 0.6937
# Epoch [32/50], Batch [2240], Total Loss: 0.2901, Diffusion Loss: 0.2190, Consistency Loss: 17.1091, Adversarial Loss: 0.6942
# Epoch [32/50], Batch [2250], Total Loss: 0.1102, Diffusion Loss: 0.0394, Consistency Loss: 13.7536, Adversarial Loss: 0.6941
# Epoch [32/50], Batch [2260], Total Loss: 0.4697, Diffusion Loss: 0.3988, Consistency Loss: 16.6643, Adversarial Loss: 0.6928
# Epoch [32/50], Batch [2270], Total Loss: 0.2351, Diffusion Loss: 0.1645, Consistency Loss: 13.1055, Adversarial Loss: 0.6924
# Epoch [32/50], Batch [2280], Total Loss: 0.3049, Diffusion Loss: 0.2338, Consistency Loss: 17.2206, Adversarial Loss: 0.6939
# Epoch [32/50], Batch [2290], Total Loss: 0.0722, Diffusion Loss: 0.0021, Consistency Loss: 8.1949, Adversarial Loss: 0.6927
# Epoch [32/50], Batch [2300], Total Loss: 0.2102, Diffusion Loss: 0.1393, Consistency Loss: 17.0056, Adversarial Loss: 0.6926
# Epoch [32/50], Batch [2310], Total Loss: 0.0966, Diffusion Loss: 0.0261, Consistency Loss: 13.2642, Adversarial Loss: 0.6927
# Epoch [32/50], Batch [2320], Total Loss: 0.3562, Diffusion Loss: 0.2852, Consistency Loss: 17.0812, Adversarial Loss: 0.6929
# Epoch [32/50], Batch [2330], Total Loss: 0.4025, Diffusion Loss: 0.3316, Consistency Loss: 17.1592, Adversarial Loss: 0.6922
# Epoch [32/50], Batch [2340], Total Loss: 0.3169, Diffusion Loss: 0.2460, Consistency Loss: 16.5570, Adversarial Loss: 0.6927
# Epoch [32/50], Batch [2350], Total Loss: 0.1277, Diffusion Loss: 0.0570, Consistency Loss: 12.6556, Adversarial Loss: 0.6936
# Epoch [32/50], Batch [2360], Total Loss: 0.0934, Diffusion Loss: 0.0227, Consistency Loss: 13.1153, Adversarial Loss: 0.6937
# Epoch [32/50], Batch [2370], Total Loss: 0.2358, Diffusion Loss: 0.1648, Consistency Loss: 17.0344, Adversarial Loss: 0.6923
# Epoch [32/50], Batch [2380], Total Loss: 0.2506, Diffusion Loss: 0.1798, Consistency Loss: 17.1322, Adversarial Loss: 0.6917
# Epoch [32/50], Batch [2390], Total Loss: 0.1282, Diffusion Loss: 0.0576, Consistency Loss: 12.8288, Adversarial Loss: 0.6938
# Epoch [32/50], Batch [2400], Total Loss: 0.4370, Diffusion Loss: 0.3660, Consistency Loss: 16.4689, Adversarial Loss: 0.6936
# Epoch [32/50], Batch [2410], Total Loss: 0.2466, Diffusion Loss: 0.1755, Consistency Loss: 17.4523, Adversarial Loss: 0.6938
# Epoch [32/50], Batch [2420], Total Loss: 0.1938, Diffusion Loss: 0.1227, Consistency Loss: 16.8391, Adversarial Loss: 0.6940
# Epoch [32/50], Batch [2430], Total Loss: 0.2145, Diffusion Loss: 0.1436, Consistency Loss: 17.2266, Adversarial Loss: 0.6927
# Epoch [32/50], Batch [2440], Total Loss: 0.0791, Diffusion Loss: 0.0088, Consistency Loss: 9.6083, Adversarial Loss: 0.6934
# Epoch [32/50], Batch [2450], Total Loss: 0.1549, Diffusion Loss: 0.0843, Consistency Loss: 13.1576, Adversarial Loss: 0.6930
# Epoch [32/50], Batch [2460], Total Loss: 0.1763, Diffusion Loss: 0.1053, Consistency Loss: 16.7687, Adversarial Loss: 0.6936
# Epoch [32/50], Batch [2470], Total Loss: 0.4958, Diffusion Loss: 0.4247, Consistency Loss: 17.1366, Adversarial Loss: 0.6939
# Epoch [32/50], Batch [2480], Total Loss: 0.1240, Diffusion Loss: 0.0533, Consistency Loss: 12.6567, Adversarial Loss: 0.6942
# Epoch [32/50], Batch [2490], Total Loss: 0.3103, Diffusion Loss: 0.2393, Consistency Loss: 17.5394, Adversarial Loss: 0.6925
# Epoch [32/50], Batch [2500], Total Loss: 0.1078, Diffusion Loss: 0.0370, Consistency Loss: 15.7367, Adversarial Loss: 0.6922
# Epoch [32/50], Batch [2510], Total Loss: 0.0897, Diffusion Loss: 0.0193, Consistency Loss: 12.2520, Adversarial Loss: 0.6920
# Epoch [32/50], Batch [2520], Total Loss: 0.1338, Diffusion Loss: 0.0628, Consistency Loss: 15.7785, Adversarial Loss: 0.6942
# Epoch [32/50], Batch [2530], Total Loss: 0.1447, Diffusion Loss: 0.0738, Consistency Loss: 15.2153, Adversarial Loss: 0.6939
# Epoch [32/50], Batch [2540], Total Loss: 0.2281, Diffusion Loss: 0.1572, Consistency Loss: 16.7795, Adversarial Loss: 0.6923
# Epoch [32/50], Batch [2550], Total Loss: 0.1929, Diffusion Loss: 0.1220, Consistency Loss: 15.7476, Adversarial Loss: 0.6938
# Epoch [32/50], Batch [2560], Total Loss: 0.5803, Diffusion Loss: 0.5092, Consistency Loss: 16.8537, Adversarial Loss: 0.6944
# Epoch [32/50], Batch [2570], Total Loss: 0.1268, Diffusion Loss: 0.0562, Consistency Loss: 13.4991, Adversarial Loss: 0.6920
# Epoch [32/50], Batch [2580], Total Loss: 0.2643, Diffusion Loss: 0.1935, Consistency Loss: 14.5556, Adversarial Loss: 0.6932
# Epoch [32/50], Batch [2590], Total Loss: 0.5108, Diffusion Loss: 0.4402, Consistency Loss: 13.4575, Adversarial Loss: 0.6933
# Epoch [32/50], Batch [2600], Total Loss: 0.2514, Diffusion Loss: 0.1806, Consistency Loss: 12.6791, Adversarial Loss: 0.6944
# Epoch [33/50], Batch [0], Total Loss: 0.0872, Diffusion Loss: 0.0169, Consistency Loss: 11.1292, Adversarial Loss: 0.6926
# Epoch [33/50], Batch [10], Total Loss: 0.5282, Diffusion Loss: 0.4572, Consistency Loss: 17.0758, Adversarial Loss: 0.6934
# Epoch [33/50], Batch [20], Total Loss: 0.1469, Diffusion Loss: 0.0759, Consistency Loss: 15.9723, Adversarial Loss: 0.6936
# Epoch [33/50], Batch [30], Total Loss: 0.2231, Diffusion Loss: 0.1520, Consistency Loss: 17.2825, Adversarial Loss: 0.6941
# Epoch [33/50], Batch [40], Total Loss: 0.1424, Diffusion Loss: 0.0717, Consistency Loss: 13.6334, Adversarial Loss: 0.6927
# Epoch [33/50], Batch [50], Total Loss: 0.5982, Diffusion Loss: 0.5272, Consistency Loss: 16.7552, Adversarial Loss: 0.6932
# Epoch [33/50], Batch [60], Total Loss: 0.3863, Diffusion Loss: 0.3155, Consistency Loss: 13.1947, Adversarial Loss: 0.6952
# Epoch [33/50], Batch [70], Total Loss: 0.4293, Diffusion Loss: 0.3583, Consistency Loss: 17.1190, Adversarial Loss: 0.6927
# Epoch [33/50], Batch [80], Total Loss: 0.1529, Diffusion Loss: 0.0819, Consistency Loss: 16.7805, Adversarial Loss: 0.6928
# Epoch [33/50], Batch [90], Total Loss: 0.2602, Diffusion Loss: 0.1892, Consistency Loss: 16.2278, Adversarial Loss: 0.6934
# Epoch [33/50], Batch [100], Total Loss: 0.2754, Diffusion Loss: 0.2043, Consistency Loss: 17.1306, Adversarial Loss: 0.6940
# Epoch [33/50], Batch [110], Total Loss: 0.1578, Diffusion Loss: 0.0869, Consistency Loss: 16.1501, Adversarial Loss: 0.6925
# Epoch [33/50], Batch [120], Total Loss: 0.0752, Diffusion Loss: 0.0050, Consistency Loss: 8.9528, Adversarial Loss: 0.6932
# Epoch [33/50], Batch [130], Total Loss: 0.1586, Diffusion Loss: 0.0878, Consistency Loss: 15.4373, Adversarial Loss: 0.6925
# Epoch [33/50], Batch [140], Total Loss: 0.1139, Diffusion Loss: 0.0434, Consistency Loss: 12.8593, Adversarial Loss: 0.6919
# Epoch [33/50], Batch [150], Total Loss: 0.0996, Diffusion Loss: 0.0291, Consistency Loss: 12.7452, Adversarial Loss: 0.6927
# Epoch [33/50], Batch [160], Total Loss: 0.0910, Diffusion Loss: 0.0205, Consistency Loss: 12.5544, Adversarial Loss: 0.6928
# Epoch [33/50], Batch [170], Total Loss: 0.0840, Diffusion Loss: 0.0135, Consistency Loss: 11.2903, Adversarial Loss: 0.6931
# Epoch [33/50], Batch [180], Total Loss: 0.0727, Diffusion Loss: 0.0026, Consistency Loss: 8.2169, Adversarial Loss: 0.6926
# Epoch [33/50], Batch [190], Total Loss: 0.1919, Diffusion Loss: 0.1213, Consistency Loss: 13.4101, Adversarial Loss: 0.6925
# Epoch [33/50], Batch [200], Total Loss: 0.1337, Diffusion Loss: 0.0630, Consistency Loss: 14.0296, Adversarial Loss: 0.6931
# Epoch [33/50], Batch [210], Total Loss: 0.1870, Diffusion Loss: 0.1160, Consistency Loss: 16.6674, Adversarial Loss: 0.6929
# Epoch [33/50], Batch [220], Total Loss: 0.2553, Diffusion Loss: 0.1841, Consistency Loss: 17.2391, Adversarial Loss: 0.6947
# Epoch [33/50], Batch [230], Total Loss: 0.1959, Diffusion Loss: 0.1249, Consistency Loss: 17.0186, Adversarial Loss: 0.6937
# Epoch [33/50], Batch [240], Total Loss: 0.1189, Diffusion Loss: 0.0482, Consistency Loss: 14.6694, Adversarial Loss: 0.6929
# Epoch [33/50], Batch [250], Total Loss: 0.1849, Diffusion Loss: 0.1139, Consistency Loss: 16.7691, Adversarial Loss: 0.6928
# Epoch [33/50], Batch [260], Total Loss: 0.1143, Diffusion Loss: 0.0435, Consistency Loss: 13.9764, Adversarial Loss: 0.6935
# Epoch [33/50], Batch [270], Total Loss: 0.1554, Diffusion Loss: 0.0845, Consistency Loss: 16.0536, Adversarial Loss: 0.6932
# Epoch [33/50], Batch [280], Total Loss: 0.1738, Diffusion Loss: 0.1032, Consistency Loss: 13.3647, Adversarial Loss: 0.6924
# Epoch [33/50], Batch [290], Total Loss: 0.0866, Diffusion Loss: 0.0161, Consistency Loss: 11.6798, Adversarial Loss: 0.6932
# Epoch [33/50], Batch [300], Total Loss: 0.1181, Diffusion Loss: 0.0472, Consistency Loss: 15.7116, Adversarial Loss: 0.6939
# Epoch [33/50], Batch [310], Total Loss: 0.3181, Diffusion Loss: 0.2474, Consistency Loss: 13.8412, Adversarial Loss: 0.6934
# Epoch [33/50], Batch [320], Total Loss: 0.2991, Diffusion Loss: 0.2283, Consistency Loss: 14.4929, Adversarial Loss: 0.6935
# Epoch [33/50], Batch [330], Total Loss: 0.1793, Diffusion Loss: 0.1085, Consistency Loss: 14.3186, Adversarial Loss: 0.6935
# Epoch [33/50], Batch [340], Total Loss: 0.0846, Diffusion Loss: 0.0142, Consistency Loss: 11.3742, Adversarial Loss: 0.6930
# Epoch [33/50], Batch [350], Total Loss: 0.2153, Diffusion Loss: 0.1448, Consistency Loss: 13.2529, Adversarial Loss: 0.6922
# Epoch [33/50], Batch [360], Total Loss: 0.2517, Diffusion Loss: 0.1812, Consistency Loss: 12.7155, Adversarial Loss: 0.6926
# Epoch [33/50], Batch [370], Total Loss: 0.1152, Diffusion Loss: 0.0446, Consistency Loss: 13.0169, Adversarial Loss: 0.6926
# Epoch [33/50], Batch [380], Total Loss: 0.7349, Diffusion Loss: 0.6637, Consistency Loss: 17.0633, Adversarial Loss: 0.6944
# Epoch [33/50], Batch [390], Total Loss: 0.1442, Diffusion Loss: 0.0734, Consistency Loss: 15.5379, Adversarial Loss: 0.6932
# Epoch [33/50], Batch [400], Total Loss: 0.2316, Diffusion Loss: 0.1607, Consistency Loss: 15.4518, Adversarial Loss: 0.6933
# Epoch [33/50], Batch [410], Total Loss: 0.6064, Diffusion Loss: 0.5355, Consistency Loss: 17.1971, Adversarial Loss: 0.6918
# Epoch [33/50], Batch [420], Total Loss: 0.1549, Diffusion Loss: 0.0839, Consistency Loss: 16.6312, Adversarial Loss: 0.6934
# Epoch [33/50], Batch [430], Total Loss: 0.5165, Diffusion Loss: 0.4459, Consistency Loss: 12.4003, Adversarial Loss: 0.6934
# Epoch [33/50], Batch [440], Total Loss: 0.2019, Diffusion Loss: 0.1309, Consistency Loss: 17.5917, Adversarial Loss: 0.6926
# Epoch [33/50], Batch [450], Total Loss: 0.4169, Diffusion Loss: 0.3457, Consistency Loss: 17.4020, Adversarial Loss: 0.6953
# Epoch [33/50], Batch [460], Total Loss: 0.2244, Diffusion Loss: 0.1535, Consistency Loss: 14.9314, Adversarial Loss: 0.6939
# Epoch [33/50], Batch [470], Total Loss: 0.1417, Diffusion Loss: 0.0708, Consistency Loss: 15.7838, Adversarial Loss: 0.6927
# Epoch [33/50], Batch [480], Total Loss: 0.1383, Diffusion Loss: 0.0677, Consistency Loss: 12.8284, Adversarial Loss: 0.6933
# Epoch [33/50], Batch [490], Total Loss: 0.1553, Diffusion Loss: 0.0843, Consistency Loss: 16.2652, Adversarial Loss: 0.6933
# Epoch [33/50], Batch [500], Total Loss: 0.1799, Diffusion Loss: 0.1091, Consistency Loss: 14.4147, Adversarial Loss: 0.6931
# Epoch [33/50], Batch [510], Total Loss: 0.0747, Diffusion Loss: 0.0046, Consistency Loss: 8.4574, Adversarial Loss: 0.6927
# Epoch [33/50], Batch [520], Total Loss: 0.2126, Diffusion Loss: 0.1415, Consistency Loss: 17.2546, Adversarial Loss: 0.6936
# Epoch [33/50], Batch [530], Total Loss: 0.1703, Diffusion Loss: 0.0996, Consistency Loss: 13.6924, Adversarial Loss: 0.6935
# Epoch [33/50], Batch [540], Total Loss: 0.1659, Diffusion Loss: 0.0950, Consistency Loss: 16.3467, Adversarial Loss: 0.6930
# Epoch [33/50], Batch [550], Total Loss: 0.0747, Diffusion Loss: 0.0045, Consistency Loss: 8.8232, Adversarial Loss: 0.6931
# Epoch [33/50], Batch [560], Total Loss: 0.1622, Diffusion Loss: 0.0911, Consistency Loss: 17.2628, Adversarial Loss: 0.6939
# Epoch [33/50], Batch [570], Total Loss: 0.1714, Diffusion Loss: 0.1003, Consistency Loss: 17.3008, Adversarial Loss: 0.6939
# Epoch [33/50], Batch [580], Total Loss: 0.1229, Diffusion Loss: 0.0521, Consistency Loss: 12.6398, Adversarial Loss: 0.6952
# Epoch [33/50], Batch [590], Total Loss: 0.1027, Diffusion Loss: 0.0320, Consistency Loss: 13.1457, Adversarial Loss: 0.6940
# Epoch [33/50], Batch [600], Total Loss: 0.2047, Diffusion Loss: 0.1337, Consistency Loss: 16.3798, Adversarial Loss: 0.6934
# Epoch [33/50], Batch [610], Total Loss: 0.1129, Diffusion Loss: 0.0421, Consistency Loss: 14.1529, Adversarial Loss: 0.6939
# Epoch [33/50], Batch [620], Total Loss: 0.1734, Diffusion Loss: 0.1022, Consistency Loss: 16.5534, Adversarial Loss: 0.6954
# Epoch [33/50], Batch [630], Total Loss: 0.0888, Diffusion Loss: 0.0183, Consistency Loss: 12.1283, Adversarial Loss: 0.6927
# Epoch [33/50], Batch [640], Total Loss: 0.1514, Diffusion Loss: 0.0803, Consistency Loss: 16.9183, Adversarial Loss: 0.6944
# Epoch [33/50], Batch [650], Total Loss: 0.2278, Diffusion Loss: 0.1568, Consistency Loss: 17.5633, Adversarial Loss: 0.6927
# Epoch [33/50], Batch [660], Total Loss: 0.0763, Diffusion Loss: 0.0060, Consistency Loss: 9.0761, Adversarial Loss: 0.6939
# Epoch [33/50], Batch [670], Total Loss: 0.0898, Diffusion Loss: 0.0193, Consistency Loss: 11.8569, Adversarial Loss: 0.6931
# Epoch [33/50], Batch [680], Total Loss: 0.1164, Diffusion Loss: 0.0457, Consistency Loss: 13.5388, Adversarial Loss: 0.6933
# Epoch [33/50], Batch [690], Total Loss: 0.3561, Diffusion Loss: 0.2852, Consistency Loss: 17.4602, Adversarial Loss: 0.6910
# Epoch [33/50], Batch [700], Total Loss: 0.1353, Diffusion Loss: 0.0646, Consistency Loss: 13.5801, Adversarial Loss: 0.6934
# Epoch [33/50], Batch [710], Total Loss: 0.1585, Diffusion Loss: 0.0875, Consistency Loss: 16.6337, Adversarial Loss: 0.6935
# Epoch [33/50], Batch [720], Total Loss: 0.1191, Diffusion Loss: 0.0485, Consistency Loss: 13.6940, Adversarial Loss: 0.6926
# Epoch [33/50], Batch [730], Total Loss: 0.7325, Diffusion Loss: 0.6617, Consistency Loss: 17.0164, Adversarial Loss: 0.6915
# Epoch [33/50], Batch [740], Total Loss: 0.1203, Diffusion Loss: 0.0496, Consistency Loss: 13.7736, Adversarial Loss: 0.6930
# Epoch [33/50], Batch [750], Total Loss: 0.1183, Diffusion Loss: 0.0475, Consistency Loss: 13.1128, Adversarial Loss: 0.6943
# Epoch [33/50], Batch [760], Total Loss: 0.0962, Diffusion Loss: 0.0257, Consistency Loss: 13.1137, Adversarial Loss: 0.6922
# Epoch [33/50], Batch [770], Total Loss: 0.0838, Diffusion Loss: 0.0133, Consistency Loss: 11.5475, Adversarial Loss: 0.6934
# Epoch [33/50], Batch [780], Total Loss: 0.3396, Diffusion Loss: 0.2689, Consistency Loss: 12.9966, Adversarial Loss: 0.6938
# Epoch [33/50], Batch [790], Total Loss: 0.1992, Diffusion Loss: 0.1282, Consistency Loss: 15.3371, Adversarial Loss: 0.6946
# Epoch [33/50], Batch [800], Total Loss: 0.0879, Diffusion Loss: 0.0175, Consistency Loss: 11.1641, Adversarial Loss: 0.6925
# Epoch [33/50], Batch [810], Total Loss: 0.0825, Diffusion Loss: 0.0121, Consistency Loss: 10.9464, Adversarial Loss: 0.6927
# Epoch [33/50], Batch [820], Total Loss: 0.1485, Diffusion Loss: 0.0778, Consistency Loss: 14.8061, Adversarial Loss: 0.6920
# ...
# Epoch [50/50], Batch [1330], Total Loss: 0.0974, Diffusion Loss: 0.0267, Consistency Loss: 14.2461, Adversarial Loss: 0.6922
# Epoch [50/50], Batch [1340], Total Loss: 0.0845, Diffusion Loss: 0.0141, Consistency Loss: 10.7549, Adversarial Loss: 0.6933
# Epoch [50/50], Batch [1350], Total Loss: 0.3638, Diffusion Loss: 0.2924, Consistency Loss: 20.8842, Adversarial Loss: 0.6929
# Epoch [50/50], Batch [1360], Total Loss: 0.2883, Diffusion Loss: 0.2169, Consistency Loss: 20.8810, Adversarial Loss: 0.6932
# Epoch [50/50], Batch [1370], Total Loss: 0.1597, Diffusion Loss: 0.0885, Consistency Loss: 18.9592, Adversarial Loss: 0.6926
# Epoch [50/50], Batch [1380], Total Loss: 0.1821, Diffusion Loss: 0.1114, Consistency Loss: 14.7930, Adversarial Loss: 0.6920
# Epoch [50/50], Batch [1390], Total Loss: 0.6107, Diffusion Loss: 0.5392, Consistency Loss: 20.9220, Adversarial Loss: 0.6943
# Epoch [50/50], Batch [1400], Total Loss: 0.1199, Diffusion Loss: 0.0491, Consistency Loss: 15.2564, Adversarial Loss: 0.6926
# Epoch [50/50], Batch [1410], Total Loss: 0.1031, Diffusion Loss: 0.0324, Consistency Loss: 13.9527, Adversarial Loss: 0.6936
# Epoch [50/50], Batch [1420], Total Loss: 0.1279, Diffusion Loss: 0.0567, Consistency Loss: 18.7475, Adversarial Loss: 0.6935
# Epoch [50/50], Batch [1430], Total Loss: 0.2178, Diffusion Loss: 0.1469, Consistency Loss: 14.6979, Adversarial Loss: 0.6938
# Epoch [50/50], Batch [1440], Total Loss: 0.3441, Diffusion Loss: 0.2727, Consistency Loss: 21.2017, Adversarial Loss: 0.6929
# Epoch [50/50], Batch [1450], Total Loss: 0.1600, Diffusion Loss: 0.0891, Consistency Loss: 14.6650, Adversarial Loss: 0.6942
# Epoch [50/50], Batch [1460], Total Loss: 0.0725, Diffusion Loss: 0.0023, Consistency Loss: 8.1150, Adversarial Loss: 0.6934
# Epoch [50/50], Batch [1470], Total Loss: 0.2443, Diffusion Loss: 0.1728, Consistency Loss: 21.0493, Adversarial Loss: 0.6942
# Epoch [50/50], Batch [1480], Total Loss: 0.0862, Diffusion Loss: 0.0157, Consistency Loss: 11.6690, Adversarial Loss: 0.6926
# Epoch [50/50], Batch [1490], Total Loss: 0.1510, Diffusion Loss: 0.0797, Consistency Loss: 20.2478, Adversarial Loss: 0.6923
# Epoch [50/50], Batch [1500], Total Loss: 0.0979, Diffusion Loss: 0.0272, Consistency Loss: 13.5142, Adversarial Loss: 0.6930
# Epoch [50/50], Batch [1510], Total Loss: 0.1100, Diffusion Loss: 0.0392, Consistency Loss: 14.2942, Adversarial Loss: 0.6939
# Epoch [50/50], Batch [1520], Total Loss: 0.1680, Diffusion Loss: 0.0968, Consistency Loss: 19.2734, Adversarial Loss: 0.6929
# Epoch [50/50], Batch [1530], Total Loss: 0.2152, Diffusion Loss: 0.1442, Consistency Loss: 16.1915, Adversarial Loss: 0.6932
# Epoch [50/50], Batch [1540], Total Loss: 0.3575, Diffusion Loss: 0.2861, Consistency Loss: 20.9093, Adversarial Loss: 0.6938
# Epoch [50/50], Batch [1550], Total Loss: 0.2376, Diffusion Loss: 0.1660, Consistency Loss: 20.8033, Adversarial Loss: 0.6945
# Epoch [50/50], Batch [1560], Total Loss: 0.0823, Diffusion Loss: 0.0119, Consistency Loss: 10.4672, Adversarial Loss: 0.6932
# Epoch [50/50], Batch [1570], Total Loss: 0.3206, Diffusion Loss: 0.2496, Consistency Loss: 17.1082, Adversarial Loss: 0.6927
# Epoch [50/50], Batch [1580], Total Loss: 0.2531, Diffusion Loss: 0.1823, Consistency Loss: 14.7929, Adversarial Loss: 0.6927
# Epoch [50/50], Batch [1590], Total Loss: 0.2548, Diffusion Loss: 0.1836, Consistency Loss: 19.5339, Adversarial Loss: 0.6933
# Epoch [50/50], Batch [1600], Total Loss: 0.3556, Diffusion Loss: 0.2843, Consistency Loss: 20.6433, Adversarial Loss: 0.6925
# Epoch [50/50], Batch [1610], Total Loss: 0.2332, Diffusion Loss: 0.1619, Consistency Loss: 19.9565, Adversarial Loss: 0.6929
# Epoch [50/50], Batch [1620], Total Loss: 0.2809, Diffusion Loss: 0.2094, Consistency Loss: 20.9676, Adversarial Loss: 0.6938
# Epoch [50/50], Batch [1630], Total Loss: 0.1090, Diffusion Loss: 0.0383, Consistency Loss: 14.3900, Adversarial Loss: 0.6931
# Epoch [50/50], Batch [1640], Total Loss: 0.1612, Diffusion Loss: 0.0898, Consistency Loss: 20.2562, Adversarial Loss: 0.6934
# Epoch [50/50], Batch [1650], Total Loss: 0.4565, Diffusion Loss: 0.3855, Consistency Loss: 16.7552, Adversarial Loss: 0.6933
# Epoch [50/50], Batch [1660], Total Loss: 0.1151, Diffusion Loss: 0.0444, Consistency Loss: 14.2145, Adversarial Loss: 0.6928
# Epoch [50/50], Batch [1670], Total Loss: 0.1573, Diffusion Loss: 0.0859, Consistency Loss: 19.5273, Adversarial Loss: 0.6939
# Epoch [50/50], Batch [1680], Total Loss: 0.0830, Diffusion Loss: 0.0126, Consistency Loss: 11.0726, Adversarial Loss: 0.6929
# Epoch [50/50], Batch [1690], Total Loss: 0.1827, Diffusion Loss: 0.1117, Consistency Loss: 17.2275, Adversarial Loss: 0.6931
# Epoch [50/50], Batch [1700], Total Loss: 0.2743, Diffusion Loss: 0.2034, Consistency Loss: 15.2175, Adversarial Loss: 0.6935
# Epoch [50/50], Batch [1710], Total Loss: 0.0911, Diffusion Loss: 0.0206, Consistency Loss: 12.9754, Adversarial Loss: 0.6927
# Epoch [50/50], Batch [1720], Total Loss: 0.2300, Diffusion Loss: 0.1585, Consistency Loss: 20.5625, Adversarial Loss: 0.6944
# Epoch [50/50], Batch [1730], Total Loss: 0.1118, Diffusion Loss: 0.0409, Consistency Loss: 15.4541, Adversarial Loss: 0.6932
# Epoch [50/50], Batch [1740], Total Loss: 0.2317, Diffusion Loss: 0.1602, Consistency Loss: 21.2131, Adversarial Loss: 0.6933
# Epoch [50/50], Batch [1750], Total Loss: 0.1108, Diffusion Loss: 0.0399, Consistency Loss: 16.0276, Adversarial Loss: 0.6930
# Epoch [50/50], Batch [1760], Total Loss: 0.0786, Diffusion Loss: 0.0083, Consistency Loss: 9.6934, Adversarial Loss: 0.6932
# Epoch [50/50], Batch [1770], Total Loss: 0.2717, Diffusion Loss: 0.2008, Consistency Loss: 15.9331, Adversarial Loss: 0.6922
# Epoch [50/50], Batch [1780], Total Loss: 0.4417, Diffusion Loss: 0.3703, Consistency Loss: 19.9886, Adversarial Loss: 0.6943
# Epoch [50/50], Batch [1790], Total Loss: 0.6181, Diffusion Loss: 0.5467, Consistency Loss: 20.9884, Adversarial Loss: 0.6928
# Epoch [50/50], Batch [1800], Total Loss: 0.1846, Diffusion Loss: 0.1138, Consistency Loss: 14.7979, Adversarial Loss: 0.6940
# Epoch [50/50], Batch [1810], Total Loss: 0.3845, Diffusion Loss: 0.3136, Consistency Loss: 16.3770, Adversarial Loss: 0.6933
# Epoch [50/50], Batch [1820], Total Loss: 0.3479, Diffusion Loss: 0.2766, Consistency Loss: 20.4895, Adversarial Loss: 0.6932
# Epoch [50/50], Batch [1830], Total Loss: 0.3675, Diffusion Loss: 0.2961, Consistency Loss: 20.8131, Adversarial Loss: 0.6932
# Epoch [50/50], Batch [1840], Total Loss: 0.1129, Diffusion Loss: 0.0419, Consistency Loss: 15.8881, Adversarial Loss: 0.6932
# Epoch [50/50], Batch [1850], Total Loss: 0.1307, Diffusion Loss: 0.0599, Consistency Loss: 15.3807, Adversarial Loss: 0.6929
# Epoch [50/50], Batch [1860], Total Loss: 0.3356, Diffusion Loss: 0.2645, Consistency Loss: 16.9895, Adversarial Loss: 0.6941
# Epoch [50/50], Batch [1870], Total Loss: 0.1152, Diffusion Loss: 0.0445, Consistency Loss: 14.2748, Adversarial Loss: 0.6932
# Epoch [50/50], Batch [1880], Total Loss: 0.1160, Diffusion Loss: 0.0449, Consistency Loss: 17.2965, Adversarial Loss: 0.6936
# Epoch [50/50], Batch [1890], Total Loss: 0.0786, Diffusion Loss: 0.0083, Consistency Loss: 9.5764, Adversarial Loss: 0.6931
# Epoch [50/50], Batch [1900], Total Loss: 0.1374, Diffusion Loss: 0.0666, Consistency Loss: 14.4765, Adversarial Loss: 0.6937
# Epoch [50/50], Batch [1910], Total Loss: 0.0913, Diffusion Loss: 0.0205, Consistency Loss: 14.6655, Adversarial Loss: 0.6934
# Epoch [50/50], Batch [1920], Total Loss: 0.1747, Diffusion Loss: 0.1036, Consistency Loss: 17.6119, Adversarial Loss: 0.6937
# Epoch [50/50], Batch [1930], Total Loss: 0.1420, Diffusion Loss: 0.0713, Consistency Loss: 14.2966, Adversarial Loss: 0.6934
# Epoch [50/50], Batch [1940], Total Loss: 0.1566, Diffusion Loss: 0.0853, Consistency Loss: 19.1843, Adversarial Loss: 0.6940
# Epoch [50/50], Batch [1950], Total Loss: 0.0800, Diffusion Loss: 0.0096, Consistency Loss: 10.2532, Adversarial Loss: 0.6938
# Epoch [50/50], Batch [1960], Total Loss: 0.3963, Diffusion Loss: 0.3250, Consistency Loss: 20.8231, Adversarial Loss: 0.6919
# Epoch [50/50], Batch [1970], Total Loss: 0.1543, Diffusion Loss: 0.0834, Consistency Loss: 16.6870, Adversarial Loss: 0.6928
# Epoch [50/50], Batch [1980], Total Loss: 0.1893, Diffusion Loss: 0.1185, Consistency Loss: 16.1233, Adversarial Loss: 0.6925
# Epoch [50/50], Batch [1990], Total Loss: 0.0865, Diffusion Loss: 0.0160, Consistency Loss: 11.7319, Adversarial Loss: 0.6934
# Epoch [50/50], Batch [2000], Total Loss: 0.0912, Diffusion Loss: 0.0206, Consistency Loss: 12.1787, Adversarial Loss: 0.6931
# Epoch [50/50], Batch [2010], Total Loss: 0.2239, Diffusion Loss: 0.1528, Consistency Loss: 17.4442, Adversarial Loss: 0.6931
# Epoch [50/50], Batch [2020], Total Loss: 0.2891, Diffusion Loss: 0.2176, Consistency Loss: 21.2656, Adversarial Loss: 0.6937
# Epoch [50/50], Batch [2030], Total Loss: 0.2753, Diffusion Loss: 0.2041, Consistency Loss: 19.9874, Adversarial Loss: 0.6915
# Epoch [50/50], Batch [2040], Total Loss: 0.2314, Diffusion Loss: 0.1607, Consistency Loss: 14.4175, Adversarial Loss: 0.6929
# Epoch [50/50], Batch [2050], Total Loss: 0.2210, Diffusion Loss: 0.1498, Consistency Loss: 18.0919, Adversarial Loss: 0.6933
# Epoch [50/50], Batch [2060], Total Loss: 0.2117, Diffusion Loss: 0.1406, Consistency Loss: 16.6559, Adversarial Loss: 0.6936
# Epoch [50/50], Batch [2070], Total Loss: 0.2158, Diffusion Loss: 0.1446, Consistency Loss: 18.9610, Adversarial Loss: 0.6932
# Epoch [50/50], Batch [2080], Total Loss: 0.0843, Diffusion Loss: 0.0138, Consistency Loss: 11.6511, Adversarial Loss: 0.6933
# Epoch [50/50], Batch [2090], Total Loss: 0.0932, Diffusion Loss: 0.0225, Consistency Loss: 13.1218, Adversarial Loss: 0.6932
# Epoch [50/50], Batch [2100], Total Loss: 0.0806, Diffusion Loss: 0.0104, Consistency Loss: 9.6698, Adversarial Loss: 0.6932
# Epoch [50/50], Batch [2110], Total Loss: 0.0843, Diffusion Loss: 0.0139, Consistency Loss: 11.6417, Adversarial Loss: 0.6925
# Epoch [50/50], Batch [2120], Total Loss: 0.2055, Diffusion Loss: 0.1342, Consistency Loss: 20.7265, Adversarial Loss: 0.6927
# Epoch [50/50], Batch [2130], Total Loss: 0.3037, Diffusion Loss: 0.2323, Consistency Loss: 20.5352, Adversarial Loss: 0.6939
# Epoch [50/50], Batch [2140], Total Loss: 0.0797, Diffusion Loss: 0.0094, Consistency Loss: 10.6029, Adversarial Loss: 0.6930
# Epoch [50/50], Batch [2150], Total Loss: 0.1157, Diffusion Loss: 0.0449, Consistency Loss: 14.1540, Adversarial Loss: 0.6932
# Epoch [50/50], Batch [2160], Total Loss: 0.3761, Diffusion Loss: 0.3047, Consistency Loss: 20.3271, Adversarial Loss: 0.6932
# Epoch [50/50], Batch [2170], Total Loss: 0.1536, Diffusion Loss: 0.0826, Consistency Loss: 15.6191, Adversarial Loss: 0.6940
# Epoch [50/50], Batch [2180], Total Loss: 0.2599, Diffusion Loss: 0.1891, Consistency Loss: 14.6974, Adversarial Loss: 0.6935
# Epoch [50/50], Batch [2190], Total Loss: 0.2970, Diffusion Loss: 0.2258, Consistency Loss: 19.6485, Adversarial Loss: 0.6928
# Epoch [50/50], Batch [2200], Total Loss: 0.0755, Diffusion Loss: 0.0053, Consistency Loss: 8.9954, Adversarial Loss: 0.6930
# Epoch [50/50], Batch [2210], Total Loss: 0.2948, Diffusion Loss: 0.2235, Consistency Loss: 18.4958, Adversarial Loss: 0.6946
# Epoch [50/50], Batch [2220], Total Loss: 0.1263, Diffusion Loss: 0.0551, Consistency Loss: 18.8061, Adversarial Loss: 0.6933
# Epoch [50/50], Batch [2230], Total Loss: 0.0739, Diffusion Loss: 0.0038, Consistency Loss: 8.1956, Adversarial Loss: 0.6930
# Epoch [50/50], Batch [2240], Total Loss: 0.2052, Diffusion Loss: 0.1343, Consistency Loss: 15.7186, Adversarial Loss: 0.6939
# Epoch [50/50], Batch [2250], Total Loss: 0.0902, Diffusion Loss: 0.0198, Consistency Loss: 12.3776, Adversarial Loss: 0.6925
# Epoch [50/50], Batch [2260], Total Loss: 0.2992, Diffusion Loss: 0.2284, Consistency Loss: 14.5748, Adversarial Loss: 0.6941
# Epoch [50/50], Batch [2270], Total Loss: 0.1531, Diffusion Loss: 0.0819, Consistency Loss: 19.9350, Adversarial Loss: 0.6927
# Epoch [50/50], Batch [2280], Total Loss: 0.2839, Diffusion Loss: 0.2125, Consistency Loss: 20.4481, Adversarial Loss: 0.6940
# Epoch [50/50], Batch [2290], Total Loss: 0.1181, Diffusion Loss: 0.0473, Consistency Loss: 15.4030, Adversarial Loss: 0.6927
# Epoch [50/50], Batch [2300], Total Loss: 0.0758, Diffusion Loss: 0.0057, Consistency Loss: 8.7560, Adversarial Loss: 0.6926
# Epoch [50/50], Batch [2310], Total Loss: 0.0835, Diffusion Loss: 0.0131, Consistency Loss: 11.2483, Adversarial Loss: 0.6929
# Epoch [50/50], Batch [2320], Total Loss: 0.0911, Diffusion Loss: 0.0205, Consistency Loss: 12.6387, Adversarial Loss: 0.6937
# Epoch [50/50], Batch [2330], Total Loss: 0.1697, Diffusion Loss: 0.0984, Consistency Loss: 19.7695, Adversarial Loss: 0.6931
# Epoch [50/50], Batch [2340], Total Loss: 0.1823, Diffusion Loss: 0.1115, Consistency Loss: 14.6636, Adversarial Loss: 0.6936
# Epoch [50/50], Batch [2350], Total Loss: 0.1237, Diffusion Loss: 0.0530, Consistency Loss: 14.3999, Adversarial Loss: 0.6928
# Epoch [50/50], Batch [2360], Total Loss: 0.1028, Diffusion Loss: 0.0320, Consistency Loss: 14.5466, Adversarial Loss: 0.6930
# Epoch [50/50], Batch [2370], Total Loss: 0.2628, Diffusion Loss: 0.1914, Consistency Loss: 20.2944, Adversarial Loss: 0.6932
# Epoch [50/50], Batch [2380], Total Loss: 0.1580, Diffusion Loss: 0.0867, Consistency Loss: 19.7838, Adversarial Loss: 0.6936
# Epoch [50/50], Batch [2390], Total Loss: 0.2097, Diffusion Loss: 0.1388, Consistency Loss: 17.0378, Adversarial Loss: 0.6924
# Epoch [50/50], Batch [2400], Total Loss: 0.2139, Diffusion Loss: 0.1431, Consistency Loss: 14.5520, Adversarial Loss: 0.6932
# Epoch [50/50], Batch [2410], Total Loss: 0.1188, Diffusion Loss: 0.0478, Consistency Loss: 16.8239, Adversarial Loss: 0.6935
# Epoch [50/50], Batch [2420], Total Loss: 0.2416, Diffusion Loss: 0.1707, Consistency Loss: 15.5017, Adversarial Loss: 0.6933
# Epoch [50/50], Batch [2430], Total Loss: 0.1940, Diffusion Loss: 0.1225, Consistency Loss: 20.4311, Adversarial Loss: 0.6943
# Epoch [50/50], Batch [2440], Total Loss: 0.2078, Diffusion Loss: 0.1366, Consistency Loss: 19.5346, Adversarial Loss: 0.6928
# Epoch [50/50], Batch [2450], Total Loss: 0.2033, Diffusion Loss: 0.1322, Consistency Loss: 19.0095, Adversarial Loss: 0.6922
# Epoch [50/50], Batch [2460], Total Loss: 0.1320, Diffusion Loss: 0.0608, Consistency Loss: 19.3658, Adversarial Loss: 0.6924
# Epoch [50/50], Batch [2470], Total Loss: 0.0783, Diffusion Loss: 0.0080, Consistency Loss: 9.7470, Adversarial Loss: 0.6932
# Epoch [50/50], Batch [2480], Total Loss: 0.3185, Diffusion Loss: 0.2474, Consistency Loss: 18.1181, Adversarial Loss: 0.6934
# Epoch [50/50], Batch [2490], Total Loss: 0.1101, Diffusion Loss: 0.0390, Consistency Loss: 18.0150, Adversarial Loss: 0.6931
# Epoch [50/50], Batch [2500], Total Loss: 0.1650, Diffusion Loss: 0.0941, Consistency Loss: 15.7071, Adversarial Loss: 0.6930
# Epoch [50/50], Batch [2510], Total Loss: 0.1014, Diffusion Loss: 0.0306, Consistency Loss: 14.8463, Adversarial Loss: 0.6931
# Epoch [50/50], Batch [2520], Total Loss: 0.2335, Diffusion Loss: 0.1627, Consistency Loss: 14.8070, Adversarial Loss: 0.6932
# Epoch [50/50], Batch [2530], Total Loss: 0.1037, Diffusion Loss: 0.0328, Consistency Loss: 15.4321, Adversarial Loss: 0.6941
# Epoch [50/50], Batch [2540], Total Loss: 0.2344, Diffusion Loss: 0.1637, Consistency Loss: 14.3013, Adversarial Loss: 0.6931
# Epoch [50/50], Batch [2550], Total Loss: 0.1328, Diffusion Loss: 0.0618, Consistency Loss: 16.6404, Adversarial Loss: 0.6931
# Epoch [50/50], Batch [2560], Total Loss: 0.1068, Diffusion Loss: 0.0359, Consistency Loss: 16.1119, Adversarial Loss: 0.6933
# Epoch [50/50], Batch [2570], Total Loss: 0.0942, Diffusion Loss: 0.0236, Consistency Loss: 13.5784, Adversarial Loss: 0.6934
# Epoch [50/50], Batch [2580], Total Loss: 0.0958, Diffusion Loss: 0.0252, Consistency Loss: 13.6994, Adversarial Loss: 0.6922
# Epoch [50/50], Batch [2590], Total Loss: 0.1080, Diffusion Loss: 0.0373, Consistency Loss: 13.5216, Adversarial Loss: 0.6927
# Epoch [50/50], Batch [2600], Total Loss: 0.2807, Diffusion Loss: 0.2092, Consistency Loss: 21.3284, Adversarial Loss: 0.6934

# %%
# Generation Function
# Generation Function
def generate_images(prompt, num_images=2, guidance_scale=7.5):
    pretrained_unet.eval()
    vae.eval()
    text_encoder.eval()
    adaptation_layers.eval()

    # Encode text prompt
    encoder_hidden_states_cond = encode_prompts([prompt] * num_images)
    encoder_hidden_states_uncond = encode_prompts([""] * num_images)
    encoder_hidden_states_full = torch.cat([encoder_hidden_states_uncond, encoder_hidden_states_cond])

    # Prepare latent variables
    latents = torch.randn((num_images, pretrained_unet.config.in_channels, 64, 64)).to(device)

    scheduler.set_timesteps(50)  # Reduce number of inference steps for speed
    timesteps = scheduler.timesteps

    for t in timesteps:
        # Expand latents for classifier-free guidance
        latent_model_input = torch.cat([latents] * 2)

        # Predict noise with adaptation layers
        # Hook function to apply adaptation layers
        def apply_adaptation(name):
            def hook(module, input, output):
                if isinstance(output, tuple):
                    out0 = output[0]
                    adaptation_layer = adaptation_layers[name]
                    adapted_out0 = adaptation_layer(out0)
                    output = (adapted_out0,) + output[1:]
                else:
                    adaptation_layer = adaptation_layers[name]
                    output = adaptation_layer(output)
                return output
            return hook

        # Register hooks
        hooks = []
        hooks.append(pretrained_unet.down_blocks[0].register_forward_hook(apply_adaptation('down_block_0')))
        hooks.append(pretrained_unet.down_blocks[1].register_forward_hook(apply_adaptation('down_block_1')))
        hooks.append(pretrained_unet.down_blocks[2].register_forward_hook(apply_adaptation('down_block_2')))
        hooks.append(pretrained_unet.mid_block.register_forward_hook(apply_adaptation('mid_block')))
        hooks.append(pretrained_unet.up_blocks[2].register_forward_hook(apply_adaptation('up_block_2')))
        hooks.append(pretrained_unet.up_blocks[1].register_forward_hook(apply_adaptation('up_block_1')))
        hooks.append(pretrained_unet.up_blocks[0].register_forward_hook(apply_adaptation('up_block_0')))

        # Predict noise
        with torch.no_grad():
            noise_pred = pretrained_unet(latent_model_input, t, encoder_hidden_states_full).sample

        # Remove hooks
        for hook in hooks:
            hook.remove()

        # Perform guidance
        noise_pred_uncond, noise_pred_cond = noise_pred.chunk(2)
        noise_pred = noise_pred_uncond + guidance_scale * (noise_pred_cond - noise_pred_uncond)

        # Update latents
        latents = scheduler.step(noise_pred, t, latents).prev_sample

    # Decode latents
    with torch.no_grad():
        images = vae.decode(1 / 0.18215 * latents).sample

    # Convert images to PIL format
    images = (images / 2 + 0.5).clamp(0, 1)
    images = images.cpu().permute(0, 2, 3, 1).numpy()
    pil_images = [Image.fromarray((img * 255).astype(np.uint8)) for img in images]

    return pil_images

# Generate and save images
generated_images = generate_images("a chest X-ray image", num_images=50)

os.makedirs('generated_images', exist_ok=True)
for idx, img in enumerate(generated_images):
    img.save(f'generated_images/generated_image_{idx}.png')
    print(f'Saved generated_images/generated_image_{idx}.png')

os.makedirs('generated_images', exist_ok=True)
for idx, img in enumerate(generated_images):
    img.save(f'generated_images/generated_image_{idx}.png')
    print(f'Saved generated_images/generated_image_{idx}.png')
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# <ipython-input-16-e962993dcbf4> in <cell line: 76>()
#      74
#      75 # Generate and save images
# ---> 76 generated_images = generate_images("a chest X-ray image", num_images=20)
#      77
#      78 os.makedirs('generated_images', exist_ok=True)
#
# <ipython-input-16-e962993dcbf4> in generate_images(prompt, num_images, guidance_scale)
#      64     # Decode latents
#      65     with torch.no_grad():
# ---> 66         images = vae.decode(1 / 0.18215 * latents).sample
#      67
#      68     # Convert images to PIL format
#
# /usr/local/lib/python3.10/dist-packages/diffusers/utils/accelerate_utils.py in wrapper(self, *args, **kwargs)
#      44         if hasattr(self, "_hf_hook") and hasattr(self._hf_hook, "pre_forward"):
#      45             self._hf_hook.pre_forward(self)
# ---> 46         return method(self, *args, **kwargs)
#      47
#      48     return wrapper
#
# /usr/local/lib/python3.10/dist-packages/diffusers/models/autoencoders/autoencoder_kl.py in decode(self, z, return_dict, generator)
#     324             decoded = torch.cat(decoded_slices)
#     325         else:
# --> 326             decoded = self._decode(z).sample
#     327
#     328         if not return_dict:
#
# /usr/local/lib/python3.10/dist-packages/diffusers/models/autoencoders/autoencoder_kl.py in _decode(self, z, return_dict)
#     295             z = self.post_quant_conv(z)
#     296
# --> 297         dec = self.decoder(z)
#     298
#     299         if not return_dict:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/diffusers/models/autoencoders/vae.py in forward(self, sample, latent_embeds)
#     335             # up
#     336             for up_block in self.up_blocks:
# --> 337                 sample = up_block(sample, latent_embeds)
#     338
#     339         # post-process
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/diffusers/models/unets/unet_2d_blocks.py in forward(self, hidden_states, temb)
#    2748         if self.upsamplers is not None:
#    2749             for upsampler in self.upsamplers:
# -> 2750                 hidden_states = upsampler(hidden_states)
#    2751
#    2752         return hidden_states
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/diffusers/models/upsampling.py in forward(self, hidden_states, output_size, *args, **kwargs)
#     178         if self.use_conv:
#     179             if self.name == "conv":
# --> 180                 hidden_states = self.conv(hidden_states)
#     181             else:
#     182                 hidden_states = self.Conv2d_0(hidden_states)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     552
#     553     def forward(self, input: Tensor) -> Tensor:
# --> 554         return self._conv_forward(input, self.weight, self.bias)
#     555
#     556
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     547                 self.groups,
#     548             )
# --> 549         return F.conv2d(
#     550             input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551         )
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 2.50 GiB. GPU 0 has a total capacity of 14.75 GiB of which 1.58 GiB is free. Process 2941 has 13.17 GiB memory in use. Of the allocated memory 9.69 GiB is allocated by PyTorch, and 3.34 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
#/content/drive/My Drive/Project/chest_xray/train

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Install required libraries
# !pip install diffusers transformers accelerate
# !pip install --upgrade diffusers  # Ensure the latest version
# !pip install huggingface_hub
# Out:
# Requirement already satisfied: diffusers in /usr/local/lib/python3.10/dist-packages (0.30.3)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.34.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers) (8.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers) (3.16.1)
# Requirement already satisfied: huggingface-hub>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from diffusers) (0.24.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from diffusers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from diffusers) (2.32.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from diffusers) (0.4.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffusers) (10.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.5.0+cu121)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.2->diffusers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.2->diffusers) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers) (3.20.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (3.0.2)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.10/dist-packages (0.30.3)
# Collecting diffusers
#   Downloading diffusers-0.31.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers) (8.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers) (3.16.1)
# Requirement already satisfied: huggingface-hub>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from diffusers) (0.24.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from diffusers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from diffusers) (2.32.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from diffusers) (0.4.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffusers) (10.4.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.2->diffusers) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.2->diffusers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.2->diffusers) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.2->diffusers) (4.66.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.2->diffusers) (4.12.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers) (3.20.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (2024.8.30)
# Downloading diffusers-0.31.0-py3-none-any.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 75.9 MB/s eta 0:00:00
# Installing collected packages: diffusers
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.30.3
#     Uninstalling diffusers-0.30.3:
#       Successfully uninstalled diffusers-0.30.3
# Successfully installed diffusers-0.31.0
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.24.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.66.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2024.8.30)

# %%
# -----------------------------------------------
# Adaptive Diffusion Network with Cross-Domain Consistency Regularization (ADN-CDCR)
# Implementation in PyTorch
# Using the Food-101 Dataset
# -----------------------------------------------

import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms, datasets
from torch.utils.data import DataLoader
from diffusers import UNet2DConditionModel, AutoencoderKL, DDPMScheduler
from transformers import CLIPTextModel, CLIPTokenizer
import torch.nn.functional as F
from torch.nn.utils import spectral_norm
import numpy as np
from PIL import Image
import os

# Set random seeds for reproducibility
torch.manual_seed(0)
np.random.seed(0)

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

# -----------------------------------------------
# 1. Dataset Preparation
# -----------------------------------------------

# Transformations
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),  # Converts to [0, 1]
    transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5]),  # Normalizes to [-1, 1]
])

# Load Food-101 Dataset
# Ensure you have enough disk space (~5GB)
dataset = datasets.Food101(
    root='.',  # Change this to your desired root directory
    split='train',
    transform=transform,
    download=True
)

print(f"Total images in the Food-101 dataset: {len(dataset)}")

# DataLoader
data_loader = DataLoader(dataset, batch_size=2, shuffle=True, num_workers=4, pin_memory=True)

# -----------------------------------------------
# 2. Model Loading
# -----------------------------------------------

# Load pre-trained models from Stable Diffusion
model_name = "stabilityai/stable-diffusion-2-1-base"

pretrained_unet = UNet2DConditionModel.from_pretrained(
    model_name, subfolder="unet"
).to(device)
pretrained_unet.eval()

vae = AutoencoderKL.from_pretrained(
    model_name, subfolder="vae"
).to(device)
vae.eval()

tokenizer = CLIPTokenizer.from_pretrained(
    model_name, subfolder="tokenizer"
)

text_encoder = CLIPTextModel.from_pretrained(
    model_name, subfolder="text_encoder"
).to(device)
text_encoder.eval()

# Freeze parameters of the pre-trained models
for param in pretrained_unet.parameters():
    param.requires_grad = False

for param in vae.parameters():
    param.requires_grad = False

for param in text_encoder.parameters():
    param.requires_grad = False

# -----------------------------------------------
# 3. Adaptation Layers and Discriminator
# -----------------------------------------------

# Adaptation layer definition with residual connections
class AdaptationLayer(nn.Module):
    def __init__(self, channels):
        super(AdaptationLayer, self).__init__()
        self.conv1 = nn.Conv2d(channels, channels, kernel_size=1, padding=0)
        self.norm1 = nn.GroupNorm(num_groups=32, num_channels=channels)
        self.relu = nn.ReLU(inplace=False)

    def forward(self, x):
        residual = x
        out = self.conv1(x)
        out = self.norm1(out)
        out = self.relu(out)
        out = out + residual
        return out

# Function to get the number of channels from the model
def get_layer_output_channels():
    dummy_input = torch.randn(1, 4, 64, 64).to(device)
    dummy_timestep = torch.tensor([0], dtype=torch.long).to(device)
    dummy_encoder_hidden_states = torch.randn(1, 77, pretrained_unet.config.cross_attention_dim).to(device)

    output_channels = {}
    output_sizes = {}

    def hook_fn(name):
        def hook(module, input, output):
            if isinstance(output, tuple):
                out = output[0]
            else:
                out = output
            output_channels[name] = out.shape[1]
            output_sizes[name] = out.shape[2:]
        return hook

    hooks = []
    for idx, block in enumerate(pretrained_unet.down_blocks):
        hooks.append(block.register_forward_hook(hook_fn(f'down_block_{idx}')))
    hooks.append(pretrained_unet.mid_block.register_forward_hook(hook_fn('mid_block')))
    for idx, block in enumerate(pretrained_unet.up_blocks):
        hooks.append(block.register_forward_hook(hook_fn(f'up_block_{idx}')))

    with torch.no_grad():
        _ = pretrained_unet(dummy_input, dummy_timestep, dummy_encoder_hidden_states)

    for hook in hooks:
        hook.remove()

    return output_channels, output_sizes

# Get actual output channels and sizes from the model
output_channels, output_sizes = get_layer_output_channels()
print("Output channels of each block:", output_channels)
print("Output sizes of each block:", output_sizes)

# Initialize adaptation layers with correct channel sizes
adaptation_layers = nn.ModuleDict()
for name, channels in output_channels.items():
    adaptation_layers[name] = AdaptationLayer(channels).to(device)

# Choose a feature map with larger spatial dimensions for the discriminator
discriminator_input_layer = 'down_block_1'  # Adjust as needed

# Discriminator network with spectral normalization
class Discriminator(nn.Module):
    def __init__(self, input_channels):
        super(Discriminator, self).__init__()
        self.main = nn.Sequential(
            spectral_norm(nn.Conv2d(input_channels, 64, kernel_size=3, stride=2, padding=1)),
            nn.LeakyReLU(0.2, inplace=False),
            spectral_norm(nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1)),
            nn.LeakyReLU(0.2, inplace=False),
            spectral_norm(nn.Conv2d(128, 256, kernel_size=3, stride=2, padding=1)),
            nn.LeakyReLU(0.2, inplace=False),
            spectral_norm(nn.Conv2d(256, 512, kernel_size=3, stride=2, padding=1)),
            nn.LeakyReLU(0.2, inplace=False),
            nn.AdaptiveAvgPool2d(1),
            nn.Conv2d(512, 1, kernel_size=1, stride=1, padding=0),
        )

    def forward(self, x):
        x = self.main(x)
        return x.view(x.size(0), -1)

discriminator = Discriminator(output_channels[discriminator_input_layer]).to(device)

# -----------------------------------------------
# 4. Loss Functions and Optimizers
# -----------------------------------------------

# Loss functions and optimizers
bce_loss = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(adaptation_layers.parameters(), lr=1e-4)
disc_optimizer = optim.Adam(discriminator.parameters(), lr=1e-6)

# Scheduler
scheduler = DDPMScheduler.from_pretrained(model_name, subfolder="scheduler")

# -----------------------------------------------
# 5. Helper Functions
# -----------------------------------------------

# Function to encode text prompts
def encode_prompts(prompts):
    text_inputs = tokenizer(
        prompts,
        padding="max_length",
        max_length=tokenizer.model_max_length,
        truncation=True,
        return_tensors="pt",
    )
    with torch.no_grad():
        text_embeddings = text_encoder(text_inputs.input_ids.to(device))[0]
    return text_embeddings

# Hook function to apply adaptation layers
def create_hook(name):
    def hook(module, input, output):
        if isinstance(output, tuple):
            # Process the first element
            out0 = output[0]
            original_features[name] = out0.detach()
            adaptation_layer = adaptation_layers[name]
            adapted_out0 = adaptation_layer(out0)
            adapted_features[name] = adapted_out0
            # Return a tuple with the adapted output and the rest unchanged
            output = (adapted_out0,) + output[1:]
        else:
            # Process the output
            original_features[name] = output.detach()
            adaptation_layer = adaptation_layers[name]
            adapted_output = adaptation_layer(output)
            adapted_features[name] = adapted_output
            output = adapted_output
        return output
    return hook

# -----------------------------------------------
# 6. Training Loop
# -----------------------------------------------

# Training loop
epochs = 10  # Adjust as needed
adv_loss_weight = 0.1
cons_loss_weight = 0.0001

for epoch in range(epochs):
    print(f"\nStarting Epoch {epoch+1}/{epochs}")
    for batch_idx, (images, labels) in enumerate(data_loader):
        images = images.to(device)
        batch_size = images.size(0)

        # Encode images to latent space
        with torch.no_grad():
            latents = vae.encode(images).latent_dist.sample() * 0.18215  # Scaling factor from Stable Diffusion

        # Generate random noise
        noise = torch.randn_like(latents).to(device)

        # Sample random timesteps
        timesteps = torch.randint(0, scheduler.config.num_train_timesteps, (batch_size,), device=device).long()

        # Get noisy latents
        noisy_latents = scheduler.add_noise(latents, noise, timesteps)

        # Convert labels to class names
        class_names = [dataset.classes[label] for label in labels]

        # Encode text prompts
        encoder_hidden_states = encode_prompts([f"a photo of {class_name}" for class_name in class_names])

        # Define dictionaries to store features for consistency loss
        adapted_features = {}
        original_features = {}

        # Register forward hooks
        hooks = []
        for idx, block in enumerate(pretrained_unet.down_blocks):
            hooks.append(block.register_forward_hook(create_hook(f'down_block_{idx}')))
        hooks.append(pretrained_unet.mid_block.register_forward_hook(create_hook('mid_block')))
        for idx, block in enumerate(pretrained_unet.up_blocks):
            hooks.append(block.register_forward_hook(create_hook(f'up_block_{idx}')))

        # Forward pass through the model with hooks
        model_pred = pretrained_unet(noisy_latents, timesteps, encoder_hidden_states).sample

        # Remove hooks
        for hook in hooks:
            hook.remove()

        # Compute losses
        # Diffusion loss
        target = noise
        diffusion_loss = F.mse_loss(model_pred, target)

        # Consistency loss
        cons_loss = 0
        for key in adapted_features.keys():
            # Ensure dimensions match
            adapted_feat = adapted_features[key]
            original_feat = original_features[key]

            # Adjust channels if needed
            if adapted_feat.shape[1] != original_feat.shape[1]:
                min_channels = min(adapted_feat.shape[1], original_feat.shape[1])
                adapted_feat = adapted_feat[:, :min_channels, :, :]
                original_feat = original_feat[:, :min_channels, :, :]

            cons_loss += F.mse_loss(adapted_feat, original_feat)

        # Adversarial loss
        # Use the feature from the selected layer as input to the discriminator
        disc_input_real = original_features[discriminator_input_layer]
        disc_input_fake = adapted_features[discriminator_input_layer]

        disc_optimizer.zero_grad()
        # Discriminator loss on real data
        disc_real = discriminator(disc_input_real.detach())
        real_labels = torch.ones_like(disc_real, device=device)
        disc_loss_real = bce_loss(disc_real, real_labels)

        # Discriminator loss on fake data
        disc_fake = discriminator(disc_input_fake.detach())
        fake_labels = torch.zeros_like(disc_fake, device=device)
        disc_loss_fake = bce_loss(disc_fake, fake_labels)

        disc_loss = (disc_loss_real + disc_loss_fake) / 2
        disc_loss.backward()
        disc_optimizer.step()

        # Generator adversarial loss
        adv_output = discriminator(disc_input_fake)
        adv_loss = bce_loss(adv_output, real_labels)

        # Total loss
        total_loss = diffusion_loss + cons_loss_weight * cons_loss + adv_loss_weight * adv_loss

        optimizer.zero_grad()
        total_loss.backward()
        optimizer.step()

        # Logging
        if batch_idx % 50 == 0:
            print(f"Epoch [{epoch+1}/{epochs}], Batch [{batch_idx}], Total Loss: {total_loss.item():.4f}, "
                  f"Diffusion Loss: {diffusion_loss.item():.4f}, Consistency Loss: {cons_loss.item():.4f}, "
                  f"Adversarial Loss: {adv_loss.item():.4f}")

# Save the trained adaptation layers
os.makedirs('saved_models', exist_ok=True)
torch.save(adaptation_layers.state_dict(), 'saved_models/adaptation_layers_food101.pth')
torch.save(discriminator.state_dict(), 'saved_models/discriminator_food101.pth')

print("Training completed and models saved.")

# -----------------------------------------------
# 7. Image Generation
# -----------------------------------------------

def generate_images(prompts, num_images=2, guidance_scale=7.5):
    pretrained_unet.eval()
    vae.eval()
    text_encoder.eval()
    adaptation_layers.eval()

    # Encode text prompt
    encoder_hidden_states_cond = encode_prompts(prompts)
    encoder_hidden_states_uncond = encode_prompts([""] * num_images)
    encoder_hidden_states_full = torch.cat([encoder_hidden_states_uncond, encoder_hidden_states_cond])

    # Prepare latent variables
    latents = torch.randn((num_images, pretrained_unet.config.in_channels, 64, 64)).to(device)

    scheduler.set_timesteps(50)  # Adjust as needed
    timesteps = scheduler.timesteps

    for t in timesteps:
        # Expand latents for classifier-free guidance
        latent_model_input = torch.cat([latents] * 2)

        # Predict noise with adaptation layers
        # Hook function to apply adaptation layers
        def apply_adaptation(name):
            def hook(module, input, output):
                if isinstance(output, tuple):
                    out0 = output[0]
                    adaptation_layer = adaptation_layers[name]
                    adapted_out0 = adaptation_layer(out0)
                    output = (adapted_out0,) + output[1:]
                else:
                    adaptation_layer = adaptation_layers[name]
                    output = adaptation_layer(output)
                return output
            return hook

        # Register hooks
        hooks = []
        for idx, block in enumerate(pretrained_unet.down_blocks):
            hooks.append(block.register_forward_hook(apply_adaptation(f'down_block_{idx}')))
        hooks.append(pretrained_unet.mid_block.register_forward_hook(apply_adaptation('mid_block')))
        for idx, block in enumerate(pretrained_unet.up_blocks):
            hooks.append(block.register_forward_hook(apply_adaptation(f'up_block_{idx}')))

        # Predict noise
        with torch.no_grad():
            noise_pred = pretrained_unet(latent_model_input, t, encoder_hidden_states_full).sample

        # Remove hooks
        for hook in hooks:
            hook.remove()

        # Perform guidance
        noise_pred_uncond, noise_pred_cond = noise_pred.chunk(2)
        noise_pred = noise_pred_uncond + guidance_scale * (noise_pred_cond - noise_pred_uncond)

        # Update latents
        latents = scheduler.step(noise_pred, t, latents).prev_sample

    # Decode latents
    with torch.no_grad():
        images = vae.decode(1 / 0.18215 * latents).sample

    # Convert images to PIL format
    images = (images / 2 + 0.5).clamp(0, 1)
    images = images.cpu().permute(0, 2, 3, 1).numpy()
    pil_images = [Image.fromarray((img * 255).astype(np.uint8)) for img in images]

    return pil_images

# Generate and save images
class_names = dataset.classes

# Generate images for each class
os.makedirs('generated_images', exist_ok=True)

for class_name in class_names[:10]:  # Generate images for first 10 classes
    print(f"Generating images for: {class_name}")
    prompts = [f"a photo of {class_name}"] * 5  # Generate 5 images per class
    generated_images = generate_images(prompts, num_images=5)

    for idx, img in enumerate(generated_images):
        img.save(f'generated_images/{class_name}_{idx}.png')
        print(f'Saved generated_images/{class_name}_{idx}.png')

print("Image generation completed and images saved.")
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# Using device: cuda
# Downloading https://data.vision.ee.ethz.ch/cvl/food-101.tar.gz to ./food-101.tar.gz
# 100%|██████████| 5.00G/5.00G [00:24<00:00, 208MB/s]
# Extracting ./food-101.tar.gz to .
# Total images in the Food-101 dataset: 75750
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# unet/config.json:   0%|          | 0.00/911 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.46G [00:00<?, ?B/s]
# vae/config.json:   0%|          | 0.00/553 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# tokenizer/tokenizer_config.json:   0%|          | 0.00/807 [00:00<?, ?B/s]
# tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer/special_tokens_map.json:   0%|          | 0.00/460 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# text_encoder/config.json:   0%|          | 0.00/613 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.36G [00:00<?, ?B/s]
# Output channels of each block: {'down_block_0': 320, 'down_block_1': 640, 'down_block_2': 1280, 'down_block_3': 1280, 'mid_block': 1280, 'up_block_0': 1280, 'up_block_1': 1280, 'up_block_2': 640, 'up_block_3': 320}
# Output sizes of each block: {'down_block_0': torch.Size([32, 32]), 'down_block_1': torch.Size([16, 16]), 'down_block_2': torch.Size([8, 8]), 'down_block_3': torch.Size([8, 8]), 'mid_block': torch.Size([8, 8]), 'up_block_0': torch.Size([16, 16]), 'up_block_1': torch.Size([32, 32]), 'up_block_2': torch.Size([64, 64]), 'up_block_3': torch.Size([64, 64])}
# scheduler/scheduler_config.json:   0%|          | 0.00/346 [00:00<?, ?B/s]
# Starting Epoch 1/10
# Epoch [1/10], Batch [0], Total Loss: 0.1352, Diffusion Loss: 0.0649, Consistency Loss: 4.5010, Adversarial Loss: 0.6978
# Epoch [1/10], Batch [50], Total Loss: 0.3670, Diffusion Loss: 0.2960, Consistency Loss: 4.5400, Adversarial Loss: 0.7057
# Epoch [1/10], Batch [100], Total Loss: 0.0811, Diffusion Loss: 0.0104, Consistency Loss: 4.5190, Adversarial Loss: 0.7026
# Epoch [1/10], Batch [150], Total Loss: 0.2714, Diffusion Loss: 0.2003, Consistency Loss: 4.6436, Adversarial Loss: 0.7064
# Epoch [1/10], Batch [200], Total Loss: 0.1350, Diffusion Loss: 0.0639, Consistency Loss: 4.6126, Adversarial Loss: 0.7066
# Epoch [1/10], Batch [250], Total Loss: 0.2314, Diffusion Loss: 0.1602, Consistency Loss: 4.7101, Adversarial Loss: 0.7072
# Epoch [1/10], Batch [300], Total Loss: 0.4619, Diffusion Loss: 0.3903, Consistency Loss: 4.7664, Adversarial Loss: 0.7107
# Epoch [1/10], Batch [350], Total Loss: 0.2140, Diffusion Loss: 0.1429, Consistency Loss: 4.6959, Adversarial Loss: 0.7066
# Epoch [1/10], Batch [400], Total Loss: 0.0783, Diffusion Loss: 0.0080, Consistency Loss: 4.5876, Adversarial Loss: 0.6987
# Epoch [1/10], Batch [450], Total Loss: 0.2093, Diffusion Loss: 0.1381, Consistency Loss: 4.8133, Adversarial Loss: 0.7071
# Epoch [1/10], Batch [500], Total Loss: 0.3932, Diffusion Loss: 0.3218, Consistency Loss: 4.8635, Adversarial Loss: 0.7089
# Epoch [1/10], Batch [550], Total Loss: 0.1431, Diffusion Loss: 0.0712, Consistency Loss: 4.7865, Adversarial Loss: 0.7142
# Epoch [1/10], Batch [600], Total Loss: 0.2971, Diffusion Loss: 0.2254, Consistency Loss: 4.8098, Adversarial Loss: 0.7115
# Epoch [1/10], Batch [650], Total Loss: 0.2938, Diffusion Loss: 0.2221, Consistency Loss: 4.9127, Adversarial Loss: 0.7117
# Epoch [1/10], Batch [700], Total Loss: 0.1621, Diffusion Loss: 0.0914, Consistency Loss: 4.8918, Adversarial Loss: 0.7027
# Epoch [1/10], Batch [750], Total Loss: 0.3487, Diffusion Loss: 0.2777, Consistency Loss: 4.9622, Adversarial Loss: 0.7047
# Epoch [1/10], Batch [800], Total Loss: 0.6747, Diffusion Loss: 0.6036, Consistency Loss: 4.9782, Adversarial Loss: 0.7068
# Epoch [1/10], Batch [850], Total Loss: 0.3638, Diffusion Loss: 0.2925, Consistency Loss: 4.9880, Adversarial Loss: 0.7074
# Epoch [1/10], Batch [900], Total Loss: 0.4346, Diffusion Loss: 0.3619, Consistency Loss: 4.9915, Adversarial Loss: 0.7212
# Epoch [1/10], Batch [950], Total Loss: 0.2229, Diffusion Loss: 0.1511, Consistency Loss: 4.9739, Adversarial Loss: 0.7129
# Epoch [1/10], Batch [1000], Total Loss: 0.1718, Diffusion Loss: 0.0995, Consistency Loss: 4.9286, Adversarial Loss: 0.7180
# Epoch [1/10], Batch [1050], Total Loss: 0.2639, Diffusion Loss: 0.1904, Consistency Loss: 5.0086, Adversarial Loss: 0.7302
# Epoch [1/10], Batch [1100], Total Loss: 0.3638, Diffusion Loss: 0.2885, Consistency Loss: 4.9724, Adversarial Loss: 0.7480
# Epoch [1/10], Batch [1150], Total Loss: 0.2102, Diffusion Loss: 0.1361, Consistency Loss: 4.9285, Adversarial Loss: 0.7367
# Epoch [1/10], Batch [1200], Total Loss: 0.5125, Diffusion Loss: 0.4357, Consistency Loss: 5.0156, Adversarial Loss: 0.7632
# Epoch [1/10], Batch [1250], Total Loss: 0.3069, Diffusion Loss: 0.2301, Consistency Loss: 5.1250, Adversarial Loss: 0.7620
# Epoch [1/10], Batch [1300], Total Loss: 0.3647, Diffusion Loss: 0.2873, Consistency Loss: 4.9991, Adversarial Loss: 0.7697
# Epoch [1/10], Batch [1350], Total Loss: 0.0952, Diffusion Loss: 0.0172, Consistency Loss: 4.9310, Adversarial Loss: 0.7748
# Epoch [1/10], Batch [1400], Total Loss: 0.1942, Diffusion Loss: 0.1104, Consistency Loss: 4.9122, Adversarial Loss: 0.8340
# Epoch [1/10], Batch [1450], Total Loss: 0.2178, Diffusion Loss: 0.1359, Consistency Loss: 5.1145, Adversarial Loss: 0.8137
# Epoch [1/10], Batch [1500], Total Loss: 0.1117, Diffusion Loss: 0.0325, Consistency Loss: 5.0160, Adversarial Loss: 0.7875
# Epoch [1/10], Batch [1550], Total Loss: 0.1359, Diffusion Loss: 0.0542, Consistency Loss: 5.0867, Adversarial Loss: 0.8121
# Epoch [1/10], Batch [1600], Total Loss: 0.5421, Diffusion Loss: 0.4433, Consistency Loss: 5.1689, Adversarial Loss: 0.9827
# Epoch [1/10], Batch [1650], Total Loss: 0.3774, Diffusion Loss: 0.2819, Consistency Loss: 5.2398, Adversarial Loss: 0.9498
# Epoch [1/10], Batch [1700], Total Loss: 0.2346, Diffusion Loss: 0.1501, Consistency Loss: 5.2369, Adversarial Loss: 0.8399
# Epoch [1/10], Batch [1750], Total Loss: 0.0816, Diffusion Loss: 0.0058, Consistency Loss: 4.9654, Adversarial Loss: 0.7535
# Epoch [1/10], Batch [1800], Total Loss: 0.3601, Diffusion Loss: 0.2696, Consistency Loss: 5.3096, Adversarial Loss: 0.8997
# Epoch [1/10], Batch [1850], Total Loss: 0.2959, Diffusion Loss: 0.2264, Consistency Loss: 5.3045, Adversarial Loss: 0.6895
# Epoch [1/10], Batch [1900], Total Loss: 0.0808, Diffusion Loss: 0.0123, Consistency Loss: 4.9943, Adversarial Loss: 0.6802
# Epoch [1/10], Batch [1950], Total Loss: 0.1994, Diffusion Loss: 0.1207, Consistency Loss: 5.3248, Adversarial Loss: 0.7825
# Epoch [1/10], Batch [2000], Total Loss: 0.0961, Diffusion Loss: 0.0222, Consistency Loss: 5.1495, Adversarial Loss: 0.7345
# Epoch [1/10], Batch [2050], Total Loss: 0.1522, Diffusion Loss: 0.0739, Consistency Loss: 5.3731, Adversarial Loss: 0.7784
# Epoch [1/10], Batch [2100], Total Loss: 0.2788, Diffusion Loss: 0.1806, Consistency Loss: 5.5035, Adversarial Loss: 0.9767
# Epoch [1/10], Batch [2150], Total Loss: 0.0904, Diffusion Loss: 0.0210, Consistency Loss: 5.2358, Adversarial Loss: 0.6894
# Epoch [1/10], Batch [2200], Total Loss: 0.4797, Diffusion Loss: 0.3740, Consistency Loss: 5.4609, Adversarial Loss: 1.0510
# Epoch [1/10], Batch [2250], Total Loss: 0.3230, Diffusion Loss: 0.2539, Consistency Loss: 5.4290, Adversarial Loss: 0.6858
# Epoch [1/10], Batch [2300], Total Loss: 0.2859, Diffusion Loss: 0.1943, Consistency Loss: 5.4920, Adversarial Loss: 0.9104
# Epoch [1/10], Batch [2350], Total Loss: 0.1524, Diffusion Loss: 0.0782, Consistency Loss: 5.5593, Adversarial Loss: 0.7367
# Epoch [1/10], Batch [2400], Total Loss: 0.2884, Diffusion Loss: 0.1917, Consistency Loss: 5.4683, Adversarial Loss: 0.9616
# Epoch [1/10], Batch [2450], Total Loss: 0.1707, Diffusion Loss: 0.1070, Consistency Loss: 5.5349, Adversarial Loss: 0.6319
# Epoch [1/10], Batch [2500], Total Loss: 0.1600, Diffusion Loss: 0.0786, Consistency Loss: 5.5294, Adversarial Loss: 0.8091
# Epoch [1/10], Batch [2550], Total Loss: 0.1656, Diffusion Loss: 0.0852, Consistency Loss: 5.4848, Adversarial Loss: 0.7991
# Epoch [1/10], Batch [2600], Total Loss: 0.3511, Diffusion Loss: 0.2476, Consistency Loss: 5.5027, Adversarial Loss: 1.0300
# Epoch [1/10], Batch [2650], Total Loss: 0.2171, Diffusion Loss: 0.1510, Consistency Loss: 5.5522, Adversarial Loss: 0.6551
# Epoch [1/10], Batch [2700], Total Loss: 0.3221, Diffusion Loss: 0.2292, Consistency Loss: 5.5528, Adversarial Loss: 0.9237
# Epoch [1/10], Batch [2750], Total Loss: 0.2279, Diffusion Loss: 0.1513, Consistency Loss: 5.4531, Adversarial Loss: 0.7605
# Epoch [1/10], Batch [2800], Total Loss: 0.1802, Diffusion Loss: 0.0930, Consistency Loss: 5.2941, Adversarial Loss: 0.8670
# Epoch [1/10], Batch [2850], Total Loss: 0.2501, Diffusion Loss: 0.1665, Consistency Loss: 5.5280, Adversarial Loss: 0.8301
# Epoch [1/10], Batch [2900], Total Loss: 0.1421, Diffusion Loss: 0.0476, Consistency Loss: 5.1923, Adversarial Loss: 0.9392
# Epoch [1/10], Batch [2950], Total Loss: 0.2011, Diffusion Loss: 0.1106, Consistency Loss: 5.2459, Adversarial Loss: 0.8991
# Epoch [1/10], Batch [3000], Total Loss: 0.2509, Diffusion Loss: 0.1831, Consistency Loss: 5.3624, Adversarial Loss: 0.6730
# Epoch [1/10], Batch [3050], Total Loss: 0.4214, Diffusion Loss: 0.3331, Consistency Loss: 5.4389, Adversarial Loss: 0.8769
# Epoch [1/10], Batch [3100], Total Loss: 0.2402, Diffusion Loss: 0.1566, Consistency Loss: 5.2897, Adversarial Loss: 0.8307
# Epoch [1/10], Batch [3150], Total Loss: 0.1034, Diffusion Loss: 0.0050, Consistency Loss: 4.5842, Adversarial Loss: 0.9796
# Epoch [1/10], Batch [3200], Total Loss: 0.2068, Diffusion Loss: 0.1317, Consistency Loss: 5.4015, Adversarial Loss: 0.7463
# Epoch [1/10], Batch [3250], Total Loss: 0.4177, Diffusion Loss: 0.3427, Consistency Loss: 5.0466, Adversarial Loss: 0.7447
# Epoch [1/10], Batch [3300], Total Loss: 0.1195, Diffusion Loss: 0.0478, Consistency Loss: 4.8980, Adversarial Loss: 0.7122
# Epoch [1/10], Batch [3350], Total Loss: 0.1985, Diffusion Loss: 0.1306, Consistency Loss: 5.3715, Adversarial Loss: 0.6736
# Epoch [1/10], Batch [3400], Total Loss: 0.3122, Diffusion Loss: 0.2542, Consistency Loss: 5.3669, Adversarial Loss: 0.5742
# Epoch [1/10], Batch [3450], Total Loss: 0.2527, Diffusion Loss: 0.1938, Consistency Loss: 5.0505, Adversarial Loss: 0.5834
# Epoch [1/10], Batch [3500], Total Loss: 0.1361, Diffusion Loss: 0.0673, Consistency Loss: 4.9500, Adversarial Loss: 0.6828
# Epoch [1/10], Batch [3550], Total Loss: 0.1932, Diffusion Loss: 0.1189, Consistency Loss: 5.0560, Adversarial Loss: 0.7379
# Epoch [1/10], Batch [3600], Total Loss: 0.3405, Diffusion Loss: 0.2816, Consistency Loss: 5.3783, Adversarial Loss: 0.5833
# Epoch [1/10], Batch [3650], Total Loss: 0.1926, Diffusion Loss: 0.1244, Consistency Loss: 5.1037, Adversarial Loss: 0.6772
# Epoch [1/10], Batch [3700], Total Loss: 0.1823, Diffusion Loss: 0.1020, Consistency Loss: 4.8236, Adversarial Loss: 0.7979
# Epoch [1/10], Batch [3750], Total Loss: 0.1752, Diffusion Loss: 0.1220, Consistency Loss: 5.3098, Adversarial Loss: 0.5269
# Epoch [1/10], Batch [3800], Total Loss: 0.2380, Diffusion Loss: 0.1783, Consistency Loss: 5.1734, Adversarial Loss: 0.5927
# Epoch [1/10], Batch [3850], Total Loss: 0.2258, Diffusion Loss: 0.1578, Consistency Loss: 5.3675, Adversarial Loss: 0.6739
# Epoch [1/10], Batch [3900], Total Loss: 0.4348, Diffusion Loss: 0.3518, Consistency Loss: 5.2581, Adversarial Loss: 0.8247
# Epoch [1/10], Batch [3950], Total Loss: 0.2109, Diffusion Loss: 0.1161, Consistency Loss: 4.8570, Adversarial Loss: 0.9430
# Epoch [1/10], Batch [4000], Total Loss: 0.1937, Diffusion Loss: 0.1184, Consistency Loss: 5.2595, Adversarial Loss: 0.7477
# Epoch [1/10], Batch [4050], Total Loss: 0.3506, Diffusion Loss: 0.2796, Consistency Loss: 5.5572, Adversarial Loss: 0.7049
# Epoch [1/10], Batch [4100], Total Loss: 0.1194, Diffusion Loss: 0.0586, Consistency Loss: 5.1885, Adversarial Loss: 0.6023
# Epoch [1/10], Batch [4150], Total Loss: 0.4291, Diffusion Loss: 0.3603, Consistency Loss: 5.5341, Adversarial Loss: 0.6816
# Epoch [1/10], Batch [4200], Total Loss: 0.1448, Diffusion Loss: 0.0749, Consistency Loss: 5.4084, Adversarial Loss: 0.6929
# Epoch [1/10], Batch [4250], Total Loss: 0.1406, Diffusion Loss: 0.0805, Consistency Loss: 5.1193, Adversarial Loss: 0.5957
# Epoch [1/10], Batch [4300], Total Loss: 0.4265, Diffusion Loss: 0.3581, Consistency Loss: 5.1555, Adversarial Loss: 0.6786
# Epoch [1/10], Batch [4350], Total Loss: 0.4408, Diffusion Loss: 0.3636, Consistency Loss: 5.5367, Adversarial Loss: 0.7668
# Epoch [1/10], Batch [4400], Total Loss: 0.1004, Diffusion Loss: 0.0364, Consistency Loss: 4.8655, Adversarial Loss: 0.6356
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-3e5de394adb3> in <cell line: 239>()
#     329
#     330         optimizer.zero_grad()
# --> 331         total_loss.backward()
#     332         optimizer.step()
#     333
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     579                 inputs=inputs,
#     580             )
# --> 581         torch.autograd.backward(
#     582             self, gradient, retain_graph, create_graph, inputs=inputs
#     583         )
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     345     # some Python versions print out the first line of a multi-line function
#     346     # calls in the traceback and some print out the last line
# --> 347     _engine_run_backward(
#     348         tensors,
#     349         grad_tensors_,
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     823         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824     try:
# --> 825         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826             t_outputs, *args, **kwargs
#     827         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
# -----------------------------------------------
# Adaptive Diffusion Network with Cross-Domain Consistency Regularization (ADN-CDCR)
# Implementation in PyTorch
# Using the Food-101 Dataset with Guided Diffusion based on Labels
# -----------------------------------------------

import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms, datasets
from torch.utils.data import DataLoader
from diffusers import UNet2DConditionModel, AutoencoderKL, DDPMScheduler
from transformers import CLIPTextModel, CLIPTokenizer
import torch.nn.functional as F
from torch.nn.utils import spectral_norm
import numpy as np
from PIL import Image
import os

# Set random seeds for reproducibility
torch.manual_seed(0)
np.random.seed(0)

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

# -----------------------------------------------
# 1. Dataset Preparation
# -----------------------------------------------

# Transformations
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),  # Converts to [0, 1]
    transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5]),  # Normalizes to [-1, 1]
])

# Load Food-101 Dataset
# Ensure you have enough disk space (~5GB)
dataset = datasets.Food101(
    root='.',  # Change this to your desired root directory
    split='train',
    transform=transform,
    download=True
)

print(f"Total images in the Food-101 dataset: {len(dataset)}")

# DataLoader
data_loader = DataLoader(dataset, batch_size=2, shuffle=True, num_workers=4, pin_memory=True)

# -----------------------------------------------
# 2. Model Loading
# -----------------------------------------------

# Load pre-trained models from Stable Diffusion
model_name = "stabilityai/stable-diffusion-2-1-base"

pretrained_unet = UNet2DConditionModel.from_pretrained(
    model_name, subfolder="unet"
).to(device)
pretrained_unet.eval()

vae = AutoencoderKL.from_pretrained(
    model_name, subfolder="vae"
).to(device)
vae.eval()

tokenizer = CLIPTokenizer.from_pretrained(
    model_name, subfolder="tokenizer"
)

text_encoder = CLIPTextModel.from_pretrained(
    model_name, subfolder="text_encoder"
).to(device)
text_encoder.eval()

# Freeze parameters of the pre-trained models
for param in pretrained_unet.parameters():
    param.requires_grad = False

for param in vae.parameters():
    param.requires_grad = False

for param in text_encoder.parameters():
    param.requires_grad = False

# -----------------------------------------------
# 3. Adaptation Layers and Discriminator
# -----------------------------------------------

# Adaptation layer definition with residual connections
class AdaptationLayer(nn.Module):
    def __init__(self, channels):
        super(AdaptationLayer, self).__init__()
        self.conv1 = nn.Conv2d(channels, channels, kernel_size=1, padding=0)
        self.norm1 = nn.GroupNorm(num_groups=32, num_channels=channels)
        self.relu = nn.ReLU(inplace=False)

    def forward(self, x):
        residual = x
        out = self.conv1(x)
        out = self.norm1(out)
        out = self.relu(out)
        out = out + residual
        return out

# Function to get the number of channels from the model
def get_layer_output_channels():
    dummy_input = torch.randn(1, 4, 64, 64).to(device)
    dummy_timestep = torch.tensor([0], dtype=torch.long).to(device)
    dummy_encoder_hidden_states = torch.randn(1, 77, pretrained_unet.config.cross_attention_dim).to(device)

    output_channels = {}
    output_sizes = {}

    def hook_fn(name):
        def hook(module, input, output):
            if isinstance(output, tuple):
                out = output[0]
            else:
                out = output
            output_channels[name] = out.shape[1]
            output_sizes[name] = out.shape[2:]
        return hook

    hooks = []
    for idx, block in enumerate(pretrained_unet.down_blocks):
        hooks.append(block.register_forward_hook(hook_fn(f'down_block_{idx}')))
    hooks.append(pretrained_unet.mid_block.register_forward_hook(hook_fn('mid_block')))
    for idx, block in enumerate(pretrained_unet.up_blocks):
        hooks.append(block.register_forward_hook(hook_fn(f'up_block_{idx}')))

    with torch.no_grad():
        _ = pretrained_unet(dummy_input, dummy_timestep, dummy_encoder_hidden_states)

    for hook in hooks:
        hook.remove()

    return output_channels, output_sizes

# Get actual output channels and sizes from the model
output_channels, output_sizes = get_layer_output_channels()
print("Output channels of each block:", output_channels)
print("Output sizes of each block:", output_sizes)

# Initialize adaptation layers with correct channel sizes
adaptation_layers = nn.ModuleDict()
for name, channels in output_channels.items():
    adaptation_layers[name] = AdaptationLayer(channels).to(device)

# Choose a feature map with larger spatial dimensions for the discriminator
discriminator_input_layer = 'down_block_1'  # Adjust as needed

# Discriminator network with spectral normalization
class Discriminator(nn.Module):
    def __init__(self, input_channels):
        super(Discriminator, self).__init__()
        self.main = nn.Sequential(
            spectral_norm(nn.Conv2d(input_channels, 64, kernel_size=3, stride=2, padding=1)),
            nn.LeakyReLU(0.2, inplace=False),
            spectral_norm(nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1)),
            nn.LeakyReLU(0.2, inplace=False),
            spectral_norm(nn.Conv2d(128, 256, kernel_size=3, stride=2, padding=1)),
            nn.LeakyReLU(0.2, inplace=False),
            spectral_norm(nn.Conv2d(256, 512, kernel_size=3, stride=2, padding=1)),
            nn.LeakyReLU(0.2, inplace=False),
            nn.AdaptiveAvgPool2d(1),
            nn.Conv2d(512, 1, kernel_size=1, stride=1, padding=0),
        )

    def forward(self, x):
        x = self.main(x)
        return x.view(x.size(0), -1)

discriminator = Discriminator(output_channels[discriminator_input_layer]).to(device)

# -----------------------------------------------
# 4. Loss Functions and Optimizers
# -----------------------------------------------

# Loss functions and optimizers
bce_loss = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(adaptation_layers.parameters(), lr=1e-4)
disc_optimizer = optim.Adam(discriminator.parameters(), lr=1e-6)

# Scheduler
scheduler = DDPMScheduler.from_pretrained(model_name, subfolder="scheduler")

# -----------------------------------------------
# 5. Helper Functions
# -----------------------------------------------

# Function to encode text prompts
def encode_prompts(prompts):
    text_inputs = tokenizer(
        prompts,
        padding="max_length",
        max_length=tokenizer.model_max_length,
        truncation=True,
        return_tensors="pt",
    )
    with torch.no_grad():
        text_embeddings = text_encoder(text_inputs.input_ids.to(device))[0]
    return text_embeddings

# Hook function to apply adaptation layers
def create_hook(name):
    def hook(module, input, output):
        if isinstance(output, tuple):
            # Process the first element
            out0 = output[0]
            original_features[name] = out0.detach()
            adaptation_layer = adaptation_layers[name]
            adapted_out0 = adaptation_layer(out0)
            adapted_features[name] = adapted_out0
            # Return a tuple with the adapted output and the rest unchanged
            output = (adapted_out0,) + output[1:]
        else:
            # Process the output
            original_features[name] = output.detach()
            adaptation_layer = adaptation_layers[name]
            adapted_output = adaptation_layer(output)
            adapted_features[name] = adapted_output
            output = adapted_output
        return output
    return hook

# -----------------------------------------------
# 6. Training Loop with Guided Diffusion
# -----------------------------------------------

# Training loop
epochs = 10  # Adjust as needed
adv_loss_weight = 0.1
cons_loss_weight = 0.0001

for epoch in range(epochs):
    print(f"\nStarting Epoch {epoch+1}/{epochs}")
    for batch_idx, (images, labels) in enumerate(data_loader):
        images = images.to(device)
        labels = labels.to(device)
        batch_size = images.size(0)

        # Encode images to latent space
        with torch.no_grad():
            latents = vae.encode(images).latent_dist.sample() * 0.18215  # Scaling factor from Stable Diffusion

        # Generate random noise
        noise = torch.randn_like(latents).to(device)

        # Sample random timesteps
        timesteps = torch.randint(0, scheduler.config.num_train_timesteps, (batch_size,), device=device).long()

        # Get noisy latents
        noisy_latents = scheduler.add_noise(latents, noise, timesteps)

        # Convert labels to class names
        class_names = [dataset.classes[label] for label in labels]

        # Encode text prompts
        encoder_hidden_states = encode_prompts([f"a photo of {class_name}" for class_name in class_names])

        # Define dictionaries to store features for consistency loss
        adapted_features = {}
        original_features = {}

        # Register forward hooks
        hooks = []
        for idx, block in enumerate(pretrained_unet.down_blocks):
            hooks.append(block.register_forward_hook(create_hook(f'down_block_{idx}')))
        hooks.append(pretrained_unet.mid_block.register_forward_hook(create_hook('mid_block')))
        for idx, block in enumerate(pretrained_unet.up_blocks):
            hooks.append(block.register_forward_hook(create_hook(f'up_block_{idx}')))

        # Forward pass through the model with hooks
        model_pred = pretrained_unet(noisy_latents, timesteps, encoder_hidden_states).sample

        # Remove hooks
        for hook in hooks:
            hook.remove()

        # Compute losses
        # Diffusion loss
        target = noise
        diffusion_loss = F.mse_loss(model_pred, target)

        # Consistency loss
        cons_loss = 0
        for key in adapted_features.keys():
            # Ensure dimensions match
            adapted_feat = adapted_features[key]
            original_feat = original_features[key]

            # Adjust channels if needed
            if adapted_feat.shape[1] != original_feat.shape[1]:
                min_channels = min(adapted_feat.shape[1], original_feat.shape[1])
                adapted_feat = adapted_feat[:, :min_channels, :, :]
                original_feat = original_feat[:, :min_channels, :, :]

            cons_loss += F.mse_loss(adapted_feat, original_feat)

        # Adversarial loss
        # Use the feature from the selected layer as input to the discriminator
        disc_input_real = original_features[discriminator_input_layer]
        disc_input_fake = adapted_features[discriminator_input_layer]

        disc_optimizer.zero_grad()
        # Discriminator loss on real data
        disc_real = discriminator(disc_input_real.detach())
        real_labels = torch.ones_like(disc_real, device=device)
        disc_loss_real = bce_loss(disc_real, real_labels)

        # Discriminator loss on fake data
        disc_fake = discriminator(disc_input_fake.detach())
        fake_labels = torch.zeros_like(disc_fake, device=device)
        disc_loss_fake = bce_loss(disc_fake, fake_labels)

        disc_loss = (disc_loss_real + disc_loss_fake) / 2
        disc_loss.backward()
        disc_optimizer.step()

        # Generator adversarial loss
        adv_output = discriminator(disc_input_fake)
        adv_loss = bce_loss(adv_output, real_labels)

        # Total loss
        total_loss = diffusion_loss + cons_loss_weight * cons_loss + adv_loss_weight * adv_loss

        optimizer.zero_grad()
        total_loss.backward()
        optimizer.step()

        # Logging
        if batch_idx % 50 == 0:
            print(f"Epoch [{epoch+1}/{epochs}], Batch [{batch_idx}], Total Loss: {total_loss.item():.4f}, "
                  f"Diffusion Loss: {diffusion_loss.item():.4f}, Consistency Loss: {cons_loss.item():.4f}, "
                  f"Adversarial Loss: {adv_loss.item():.4f}")

# Save the trained adaptation layers
os.makedirs('saved_models', exist_ok=True)
torch.save(adaptation_layers.state_dict(), 'saved_models/adaptation_layers_food101.pth')
torch.save(discriminator.state_dict(), 'saved_models/discriminator_food101.pth')

print("Training completed and models saved.")

# -----------------------------------------------
# 7. Image Generation with Guided Diffusion
# -----------------------------------------------

def generate_images(labels, num_images=1, guidance_scale=7.5):
    pretrained_unet.eval()
    vae.eval()
    text_encoder.eval()
    adaptation_layers.eval()

    # Convert labels to class names
    class_names = [dataset.classes[label] for label in labels]

    # Encode text prompts
    prompts = [f"a photo of {class_name}" for class_name in class_names]
    encoder_hidden_states_cond = encode_prompts(prompts)
    encoder_hidden_states_uncond = encode_prompts([""] * num_images)
    encoder_hidden_states_full = torch.cat([encoder_hidden_states_uncond, encoder_hidden_states_cond])

    # Prepare latent variables
    latents = torch.randn((num_images, pretrained_unet.config.in_channels, 64, 64)).to(device)

    scheduler.set_timesteps(50)  # Adjust as needed
    timesteps = scheduler.timesteps

    for t in timesteps:
        # Expand latents for classifier-free guidance
        latent_model_input = torch.cat([latents] * 2)

        # Predict noise with adaptation layers
        # Hook function to apply adaptation layers
        def apply_adaptation(name):
            def hook(module, input, output):
                if isinstance(output, tuple):
                    out0 = output[0]
                    adaptation_layer = adaptation_layers[name]
                    adapted_out0 = adaptation_layer(out0)
                    output = (adapted_out0,) + output[1:]
                else:
                    adaptation_layer = adaptation_layers[name]
                    output = adaptation_layer(output)
                return output
            return hook

        # Register hooks
        hooks = []
        for idx, block in enumerate(pretrained_unet.down_blocks):
            hooks.append(block.register_forward_hook(apply_adaptation(f'down_block_{idx}')))
        hooks.append(pretrained_unet.mid_block.register_forward_hook(apply_adaptation('mid_block')))
        for idx, block in enumerate(pretrained_unet.up_blocks):
            hooks.append(block.register_forward_hook(apply_adaptation(f'up_block_{idx}')))

        # Predict noise
        with torch.no_grad():
            noise_pred = pretrained_unet(latent_model_input, t, encoder_hidden_states_full).sample

        # Remove hooks
        for hook in hooks:
            hook.remove()

        # Perform guidance
        noise_pred_uncond, noise_pred_cond = noise_pred.chunk(2)
        noise_pred = noise_pred_uncond + guidance_scale * (noise_pred_cond - noise_pred_uncond)

        # Update latents
        latents = scheduler.step(noise_pred, t, latents).prev_sample

    # Decode latents
    with torch.no_grad():
        images = vae.decode(1 / 0.18215 * latents).sample

    # Convert images to PIL format
    images = (images / 2 + 0.5).clamp(0, 1)
    images = images.cpu().permute(0, 2, 3, 1).numpy()
    pil_images = [Image.fromarray((img * 255).astype(np.uint8)) for img in images]

    return pil_images

# Generate and save images based on labels
os.makedirs('generated_images', exist_ok=True)

# Example: Generate images for specific labels
# Let's generate images for the first 10 classes
num_classes_to_generate = 10
images_per_class = 5

for label_idx in range(num_classes_to_generate):
    print(f"Generating images for class: {dataset.classes[label_idx]}")
    labels = [label_idx] * images_per_class
    generated_images = generate_images(labels, num_images=images_per_class)

    for idx, img in enumerate(generated_images):
        img.save(f'generated_images/{dataset.classes[label_idx]}_{idx}.png')
        print(f'Saved generated_images/{dataset.classes[label_idx]}_{idx}.png')

print("Image generation completed and images saved.")
# Out:
# Using device: cuda
# Total images in the Food-101 dataset: 75750
# Output channels of each block: {'down_block_0': 320, 'down_block_1': 640, 'down_block_2': 1280, 'down_block_3': 1280, 'mid_block': 1280, 'up_block_0': 1280, 'up_block_1': 1280, 'up_block_2': 640, 'up_block_3': 320}
# Output sizes of each block: {'down_block_0': torch.Size([32, 32]), 'down_block_1': torch.Size([16, 16]), 'down_block_2': torch.Size([8, 8]), 'down_block_3': torch.Size([8, 8]), 'mid_block': torch.Size([8, 8]), 'up_block_0': torch.Size([16, 16]), 'up_block_1': torch.Size([32, 32]), 'up_block_2': torch.Size([64, 64]), 'up_block_3': torch.Size([64, 64])}
#
# Starting Epoch 1/10
# Epoch [1/10], Batch [0], Total Loss: 0.1352, Diffusion Loss: 0.0649, Consistency Loss: 4.5010, Adversarial Loss: 0.6978
# Epoch [1/10], Batch [50], Total Loss: 0.3670, Diffusion Loss: 0.2960, Consistency Loss: 4.5400, Adversarial Loss: 0.7057
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-b23dda74cbbd> in <cell line: 239>()
#     276
#     277         # Forward pass through the model with hooks
# --> 278         model_pred = pretrained_unet(noisy_latents, timesteps, encoder_hidden_states).sample
#     279
#     280         # Remove hooks
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/diffusers/models/unets/unet_2d_condition.py in forward(self, sample, timestep, encoder_hidden_states, class_labels, timestep_cond, attention_mask, cross_attention_kwargs, added_cond_kwargs, down_block_additional_residuals, mid_block_additional_residual, down_intrablock_additional_residuals, encoder_attention_mask, return_dict)
#    1279
#    1280             if hasattr(upsample_block, "has_cross_attention") and upsample_block.has_cross_attention:
# -> 1281                 sample = upsample_block(
#    1282                     hidden_states=sample,
#    1283                     temb=emb,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1842
#    1843         try:
# -> 1844             return inner()
#    1845         except Exception:
#    1846             # run always called hooks if they have not already been run
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in inner()
#    1788                 args = bw_hook.setup_input_hook(args)
#    1789
# -> 1790             result = forward_call(*args, **kwargs)
#    1791             if _global_forward_hooks or self._forward_hooks:
#    1792                 for hook_id, hook in (
#
# /usr/local/lib/python3.10/dist-packages/diffusers/models/unets/unet_2d_blocks.py in forward(self, hidden_states, res_hidden_states_tuple, temb, encoder_hidden_states, cross_attention_kwargs, upsample_size, attention_mask, encoder_attention_mask)
#    2548                 )[0]
#    2549             else:
# -> 2550                 hidden_states = resnet(hidden_states, temb)
#    2551                 hidden_states = attn(
#    2552                     hidden_states,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/diffusers/models/resnet.py in forward(self, input_tensor, temb, *args, **kwargs)
#     339             hidden_states = self.downsample(hidden_states)
#     340
# --> 341         hidden_states = self.conv1(hidden_states)
#     342
#     343         if self.time_emb_proj is not None:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     552
#     553     def forward(self, input: Tensor) -> Tensor:
# --> 554         return self._conv_forward(input, self.weight, self.bias)
#     555
#     556
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     547                 self.groups,
#     548             )
# --> 549         return F.conv2d(
#     550             input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551         )
#
# KeyboardInterrupt:
